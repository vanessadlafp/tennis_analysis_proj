# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import scipy


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#For standardizing features

from sklearn.preprocessing import StandardScaler

#Hierarchical clustering with the Sci Py library. We'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# ## Load the data

# %%
df_players_2019= pd.read_csv("players_2019.csv")

# %% [markdown]
# ## Data exploration

# %% [markdown]
# ### Players' performance 2019

# %%
df_players_2019.head()
# Out:
#    Unnamed: 0  Ranking  Move  Country           Player  Age  Points  \
# 0           0        1   NaN      NaN     Rafael Nadal   33    9985
# 1           1        2   NaN      NaN   Novak Djokovic   32    9145
# 2           2        3   NaN      NaN    Roger Federer   38    6590
# 3           3        4   NaN      NaN    Dominic Thiem   26    5825
# 4           4        5   NaN      NaN  Daniil Medvedev   23    5705
#
#    Tourn Played  Points Dropping  Next Best  ...  Service Games Won  \
# 0            17                0          0  ...                90%
# 1            17               90          0  ...                88%
# 2            17                0          0  ...                91%
# 3            22                0          0  ...                84%
# 4            24                0          0  ...                84%
#
#    Total Service Points Won  1st Serve Return Points Won  \
# 0                       70%                          35%
# 1                       69%                          34%
# 2                       72%                          32%
# 3                       67%                          29%
# 4                       67%                          31%
#
#    2nd Serve Return Points Won Break Points Opportunities  \
# 0                          56%                        556
# 1                          54%                        516
# 2                          50%                        507
# 3                          51%                        466
# 4                          56%                        622
#
#   Break Points Converted Return Games Played  Return Games Won  \
# 0                    45%                 715               35%
# 1                    49%                 796               32%
# 2                    41%                 809               25%
# 3                    41%                 823               23%
# 4                    43%                 963               28%
#
#   Return Points Won  Total Points Won
# 0               42%               56%
# 1               42%               55%
# 2               39%               55%
# 3               37%               52%
# 4               40%               53%
#
# [5 rows x 30 columns]

# %%
df_players_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   100 non-null    int64
#  1   Ranking                      100 non-null    int64
#  2   Move                         0 non-null      float64
#  3   Country                      0 non-null      float64
#  4   Player                       100 non-null    object
#  5   Age                          100 non-null    int64
#  6   Points                       100 non-null    int64
#  7   Tourn Played                 100 non-null    int64
#  8   Points Dropping              100 non-null    int64
#  9   Next Best                    100 non-null    int64
#  10  Turned Pro                   100 non-null    int64
#  11  index                        100 non-null    int64
#  12  Aces                         100 non-null    int64
#  13  Double Faults                100 non-null    int64
#  14  1st Serve                    100 non-null    object
#  15  1st Serve Points Won         100 non-null    object
#  16  2nd Serve Points Won         100 non-null    object
#  17  Break Points Faced           100 non-null    int64
#  18  Break Points Saved           100 non-null    object
#  19  Service Games Played         100 non-null    int64
#  20  Service Games Won            100 non-null    object
#  21  Total Service Points Won     100 non-null    object
#  22  1st Serve Return Points Won  100 non-null    object
#  23  2nd Serve Return Points Won  100 non-null    object
#  24  Break Points Opportunities   100 non-null    int64
#  25  Break Points Converted       100 non-null    object
#  26  Return Games Played          100 non-null    int64
#  27  Return Games Won             100 non-null    object
#  28  Return Points Won            100 non-null    object
#  29  Total Points Won             100 non-null    object
# dtypes: float64(2), int64(15), object(13)
# memory usage: 23.6+ KB

# %% [markdown]
# We see some columns with  numeric values aren't considered as such due to they have the percentage symbols next to it
# and that columns Move and Country have NaN values

# %%
df_players_2019= df_players_2019.drop(['Unnamed: 0', 'Move', 'Country', 'Points Dropping', 'Next Best','index'], axis=1)
df_players_2019
# Out:
#     Ranking            Player  Age  Points  Tourn Played  Turned Pro  Aces  \
# 0         1      Rafael Nadal   33    9985            17        2001   271
# 1         2    Novak Djokovic   32    9145            17        2003   373
# 2         3     Roger Federer   38    6590            17        1998   481
# 3         4     Dominic Thiem   26    5825            22        2011   314
# 4         5   Daniil Medvedev   23    5705            24        2014   690
# ..      ...               ...  ...     ...           ...         ...   ...
# 95       96  Salvatore Caruso   27     586            28        2010    11
# 96       97    Alexei Popyrin   20     585            25        2017   248
# 97       98    Egor Gerasimov   27     581            23        2010   130
# 98       99      Lloyd Harris   22     576            24        2015   200
# 99      100   James Duckworth   27     576            28        2010    26
#
#     Double Faults 1st Serve 1st Serve Points Won  ... Service Games Won  \
# 0             118       65%                  76%  ...               90%
# 1             166       66%                  76%  ...               88%
# 2             100       65%                  78%  ...               91%
# 3             138       66%                  73%  ...               84%
# 4             254       60%                  76%  ...               84%
# ..            ...       ...                  ...  ...               ...
# 95             17       69%                  62%  ...               70%
# 96            121       61%                  73%  ...               81%
# 97             38       67%                  74%  ...               83%
# 98             57       62%                  72%  ...               74%
# 99             15       59%                  69%  ...               69%
#
#     Total Service Points Won 1st Serve Return Points Won  \
# 0                        70%                         35%
# 1                        69%                         34%
# 2                        72%                         32%
# 3                        67%                         29%
# 4                        67%                         31%
# ..                       ...                         ...
# 95                       58%                         32%
# 96                       64%                         25%
# 97                       67%                         26%
# 98                       61%                         25%
# 99                       58%                         26%
#
#     2nd Serve Return Points Won Break Points Opportunities  \
# 0                           56%                        556
# 1                           54%                        516
# 2                           50%                        507
# 3                           51%                        466
# 4                           56%                        622
# ..                          ...                        ...
# 95                          54%                         88
# 96                          43%                        174
# 97                          51%                         89
# 98                          45%                        100
# 99                          41%                         10
#
#    Break Points Converted Return Games Played Return Games Won  \
# 0                     45%                 715              35%
# 1                     49%                 796              32%
# 2                     41%                 809              25%
# 3                     41%                 823              23%
# 4                     43%                 963              28%
# ..                    ...                 ...              ...
# 95                    47%                 134              31%
# 96                    33%                 405              14%
# 97                    27%                 186              13%
# 98                    45%                 255              18%
# 99                    50%                  39              13%
#
#     Return Points Won Total Points Won
# 0                 42%              56%
# 1                 42%              55%
# 2                 39%              55%
# 3                 37%              52%
# 4                 40%              53%
# ..                ...              ...
# 95                41%              49%
# 96                32%              49%
# 97                35%              50%
# 98                33%              48%
# 99                32%              46%
#
# [100 rows x 24 columns]

# %%
df_players_2019['1st Serve']= df_players_2019['1st Serve'].apply(lambda x: int(x.strip('%')))
df_players_2019['1st Serve Points Won']= df_players_2019['1st Serve Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['2nd Serve Points Won']= df_players_2019['2nd Serve Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['Break Points Saved']= df_players_2019['Break Points Saved'].apply(lambda x: int(x.strip('%')))
df_players_2019['Service Games Won']= df_players_2019['Service Games Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['Total Service Points Won']= df_players_2019['Total Service Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['1st Serve Return Points Won']= df_players_2019['1st Serve Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['2nd Serve Return Points Won']= df_players_2019['2nd Serve Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['Break Points Converted']= df_players_2019['Break Points Converted'].apply(lambda x: int(x.strip('%')))
df_players_2019['Return Games Won']= df_players_2019['Return Games Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['Return Points Won']= df_players_2019['Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2019['Total Points Won']= df_players_2019['Total Points Won'].apply(lambda x: int(x.strip('%')))

df_players_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ranking                      100 non-null    int64
#  1   Player                       100 non-null    object
#  2   Age                          100 non-null    int64
#  3   Points                       100 non-null    int64
#  4   Tourn Played                 100 non-null    int64
#  5   Turned Pro                   100 non-null    int64
#  6   Aces                         100 non-null    int64
#  7   Double Faults                100 non-null    int64
#  8   1st Serve                    100 non-null    int64
#  9   1st Serve Points Won         100 non-null    int64
#  10  2nd Serve Points Won         100 non-null    int64
#  11  Break Points Faced           100 non-null    int64
#  12  Break Points Saved           100 non-null    int64
#  13  Service Games Played         100 non-null    int64
#  14  Service Games Won            100 non-null    int64
#  15  Total Service Points Won     100 non-null    int64
#  16  1st Serve Return Points Won  100 non-null    int64
#  17  2nd Serve Return Points Won  100 non-null    int64
#  18  Break Points Opportunities   100 non-null    int64
#  19  Break Points Converted       100 non-null    int64
#  20  Return Games Played          100 non-null    int64
#  21  Return Games Won             100 non-null    int64
#  22  Return Points Won            100 non-null    int64
#  23  Total Points Won             100 non-null    int64
# dtypes: int64(23), object(1)
# memory usage: 18.9+ KB

# %%
df_players_2019.columns
# Out:
# Index(['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Turned Pro',
#        'Aces', 'Double Faults', '1st Serve', '1st Serve Points Won',
#        '2nd Serve Points Won', 'Break Points Faced', 'Break Points Saved',
#        'Service Games Played', 'Service Games Won', 'Total Service Points Won',
#        '1st Serve Return Points Won', '2nd Serve Return Points Won',
#        'Break Points Opportunities', 'Break Points Converted',
#        'Return Games Played', 'Return Games Won', 'Return Points Won',
#        'Total Points Won'],
#       dtype='object')

# %%
cols= ['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Turned Pro',
       'Aces', 'Double Faults', '1st Serve %', '1st Serve Points Won %',
       '2nd Serve Points Won %', 'Break Points Faced', 'Break Points Saved %',
       'Service Games Played', 'Service Games Won %', 'Total Service Points Won %',
       '1st Serve Return Points Won %', '2nd Serve Return Points Won %',
       'Break Points Opportunities', 'Break Points Converted %',
       'Return Games Played', 'Return Games Won %', 'Return Points Won %',
       'Total Points Won %']


df_players_2019.columns= cols

# %%
df_players_2019
# Out:
#     Ranking            Player  Age  Points  Tourn Played  Turned Pro  Aces  \
# 0         1      Rafael Nadal   33    9985            17        2001   271
# 1         2    Novak Djokovic   32    9145            17        2003   373
# 2         3     Roger Federer   38    6590            17        1998   481
# 3         4     Dominic Thiem   26    5825            22        2011   314
# 4         5   Daniil Medvedev   23    5705            24        2014   690
# ..      ...               ...  ...     ...           ...         ...   ...
# 95       96  Salvatore Caruso   27     586            28        2010    11
# 96       97    Alexei Popyrin   20     585            25        2017   248
# 97       98    Egor Gerasimov   27     581            23        2010   130
# 98       99      Lloyd Harris   22     576            24        2015   200
# 99      100   James Duckworth   27     576            28        2010    26
#
#     Double Faults  1st Serve %  1st Serve Points Won %  ...  \
# 0             118           65                      76  ...
# 1             166           66                      76  ...
# 2             100           65                      78  ...
# 3             138           66                      73  ...
# 4             254           60                      76  ...
# ..            ...          ...                     ...  ...
# 95             17           69                      62  ...
# 96            121           61                      73  ...
# 97             38           67                      74  ...
# 98             57           62                      72  ...
# 99             15           59                      69  ...
#
#     Service Games Won %  Total Service Points Won %  \
# 0                    90                          70
# 1                    88                          69
# 2                    91                          72
# 3                    84                          67
# 4                    84                          67
# ..                  ...                         ...
# 95                   70                          58
# 96                   81                          64
# 97                   83                          67
# 98                   74                          61
# 99                   69                          58
#
#     1st Serve Return Points Won %  2nd Serve Return Points Won %  \
# 0                              35                             56
# 1                              34                             54
# 2                              32                             50
# 3                              29                             51
# 4                              31                             56
# ..                            ...                            ...
# 95                             32                             54
# 96                             25                             43
# 97                             26                             51
# 98                             25                             45
# 99                             26                             41
#
#     Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 0                          556                        45                  715
# 1                          516                        49                  796
# 2                          507                        41                  809
# 3                          466                        41                  823
# 4                          622                        43                  963
# ..                         ...                       ...                  ...
# 95                          88                        47                  134
# 96                         174                        33                  405
# 97                          89                        27                  186
# 98                         100                        45                  255
# 99                          10                        50                   39
#
#     Return Games Won %  Return Points Won %  Total Points Won %
# 0                   35                   42                  56
# 1                   32                   42                  55
# 2                   25                   39                  55
# 3                   23                   37                  52
# 4                   28                   40                  53
# ..                 ...                  ...                 ...
# 95                  31                   41                  49
# 96                  14                   32                  49
# 97                  13                   35                  50
# 98                  18                   33                  48
# 99                  13                   32                  46
#
# [100 rows x 24 columns]

# %%
df_players_2019['Career Length']= 2019- df_players_2019['Turned Pro']
df_players_2019= df_players_2019.drop(['Turned Pro'], axis=1)
df_players_2019['Career Length']
# Out:
# 0     18
# 1     16
# 2     21
# 3      8
# 4      5
#       ..
# 95     9
# 96     2
# 97     9
# 98     4
# 99     9
# Name: Career Length, Length: 100, dtype: int64

# %%
df_players_2019.describe()
# Out:
#           Ranking         Age       Points  Tourn Played         Aces  \
# count  100.000000  100.000000   100.000000    100.000000   100.000000
# mean    50.500000   27.200000  1493.790000     24.570000   286.920000
# std     29.011492    4.933907  1587.881819      3.704365   205.264485
# min      1.000000   18.000000   576.000000     14.000000    11.000000
# 25%     25.750000   23.000000   740.250000     23.000000   145.750000
# 50%     50.500000   27.000000  1003.500000     25.000000   243.000000
# 75%     75.250000   31.000000  1470.000000     27.000000   371.250000
# max    100.000000   40.000000  9985.000000     33.000000  1032.000000
#
#        Double Faults  1st Serve %  1st Serve Points Won %  \
# count     100.000000   100.000000               100.00000
# mean      122.620000    62.460000                72.16000
# std        70.525986     3.594103                 4.64871
# min         5.000000    52.000000                61.00000
# 25%        83.500000    60.000000                69.00000
# 50%       116.500000    62.000000                72.00000
# 75%       152.500000    65.000000                75.00000
# max       410.000000    72.000000                84.00000
#
#        2nd Serve Points Won %  Break Points Faced  ...  \
# count              100.000000          100.000000  ...
# mean                51.230000          262.860000  ...
# std                  3.168197          106.605666  ...
# min                 43.000000           25.000000  ...
# 25%                 49.000000          201.250000  ...
# 50%                 51.500000          282.000000  ...
# 75%                 53.000000          333.250000  ...
# max                 60.000000          461.000000  ...
#
#        Total Service Points Won %  1st Serve Return Points Won %  \
# count                  100.000000                     100.000000
# mean                    64.240000                      28.270000
# std                      3.417483                       2.714923
# min                     57.000000                      20.000000
# 25%                     62.000000                      27.000000
# 50%                     64.000000                      28.000000
# 75%                     66.000000                      30.000000
# max                     74.000000                      35.000000
#
#        2nd Serve Return Points Won %  Break Points Opportunities  \
# count                     100.000000                  100.000000
# mean                       49.180000                  283.740000
# std                         3.373635                  138.844337
# min                        36.000000                   10.000000
# 25%                        47.000000                  195.000000
# 50%                        49.000000                  281.000000
# 75%                        51.000000                  375.750000
# max                        56.000000                  622.000000
#
#        Break Points Converted %  Return Games Played  Return Games Won %  \
# count                100.000000            100.00000           100.00000
# mean                  39.060000            524.79000            20.71000
# std                    5.050893            212.26105             4.84569
# min                   27.000000             39.00000             5.00000
# 25%                   36.000000            419.00000            18.00000
# 50%                   39.000000            552.50000            20.50000
# 75%                   42.000000            669.75000            24.00000
# max                   61.000000           1028.00000            35.00000
#
#        Return Points Won %  Total Points Won %  Career Length
# count           100.000000          100.000000     100.000000
# mean             36.200000           50.180000       9.300000
# std               2.821276            1.546452       5.022173
# min              25.000000           46.000000       0.000000
# 25%              35.000000           49.000000       5.000000
# 50%              36.000000           50.000000       9.000000
# 75%              38.000000           51.000000      12.250000
# max              42.000000           56.000000      22.000000
#
# [8 rows x 23 columns]

# %%
df_players_2019.sort_values(by='Career Length',ascending=False)
# Out:
#     Ranking                       Player  Age  Points  Tourn Played  Aces  \
# 61       62              Feliciano Lopez   38     888            19   335
# 2         3                Roger Federer   38    6590            17   481
# 94       95                 Ivo Karlovic   40     586            21   616
# 0         1                 Rafael Nadal   33    9985            17   271
# 78       79        Philipp Kohlschreiber   36     665            26   184
# ..      ...                          ...  ...     ...           ...   ...
# 14       15             Denis Shapovalov   20    2050            26   456
# 58       59            Miomir Kecmanovic   20     901            26   166
# 20       21        Felix Auger-Aliassime   19    1636            25   475
# 77       78                Jannik Sinner   18     671            25    78
# 86       87  Alejandro Davidovich Fokina   20     627            23    29
#
#     Double Faults  1st Serve %  1st Serve Points Won %  \
# 61            109           57                      78
# 2             100           65                      78
# 94            111           66                      83
# 0             118           65                      76
# 78             70           61                      71
# ..            ...          ...                     ...
# 14            242           60                      76
# 58            102           61                      72
# 20            247           65                      75
# 77             36           59                      70
# 86             38           67                      61
#
#     2nd Serve Points Won %  ...  Total Service Points Won %  \
# 61                      52  ...                          67
# 2                       59  ...                          72
# 94                      54  ...                          73
# 0                       60  ...                          70
# 78                      55  ...                          65
# ..                     ...  ...                         ...
# 14                      52  ...                          67
# 58                      55  ...                          65
# 20                      49  ...                          66
# 77                      53  ...                          63
# 86                      47  ...                          57
#
#     1st Serve Return Points Won %  2nd Serve Return Points Won %  \
# 61                             26                             43
# 2                              32                             50
# 94                             20                             36
# 0                              35                             56
# 78                             28                             49
# ..                            ...                            ...
# 14                             29                             47
# 58                             25                             52
# 20                             28                             48
# 77                             31                             49
# 86                             31                             49
#
#     Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 61                         169                        30                  391
# 2                          507                        41                  809
# 94                          63                        29                  397
# 0                          556                        45                  715
# 78                         245                        35                  452
# ..                         ...                       ...                  ...
# 14                         343                        38                  690
# 58                         267                        39                  523
# 20                         306                        41                  641
# 77                         144                        38                  229
# 86                          75                        44                  150
#
#     Return Games Won %  Return Points Won %  Total Points Won %  Career Length
# 61                  13                   32                  49             22
# 2                   25                   39                  55             21
# 94                   5                   25                  49             19
# 0                   35                   42                  56             18
# 78                  19                   36                  50             18
# ..                 ...                  ...                 ...            ...
# 14                  19                   36                  51              2
# 58                  20                   35                  50              2
# 20                  19                   35                  51              2
# 77                  24                   37                  50              1
# 86                  22                   36                  47              0
#
# [100 rows x 24 columns]

# %%
categorical_data= df_players_2019.select_dtypes('object')
numerical_data= df_players_2019.select_dtypes('number')

# %%
#Distribution of all numeric categories

for i in numerical_data.columns:
    sns.histplot(numerical_data[i])
    plt.title(i,fontsize=13, fontweight= "bold")
    plt.show()

# %%
#Distribution of all numeric categories, evaluating outliers

for i in numerical_data.columns:
    sns.boxplot(numerical_data[i])
    plt.title(i,fontsize=13, fontweight= "bold")
    plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We'll plot the correlations using a Heat Map. 

plt.figure(figsize = (12, 9))
s = sns.heatmap(df_players_2019.corr(),
               cmap = 'RdBu',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# We see a high correlation between age and Career Length

# %% [markdown]
# ## Visualize Raw Data

# %%
# We'll plot the data. We create a 12 by 9 inches figure.
# We have 2000 data points, which we'll scatter acrros Age and Income, located on positions 2 and 4 in our data set. 
plt.figure(figsize = (12, 9))
plt.scatter(df_players_2019.iloc[:, 5], df_players_2019.iloc[:, 0])
plt.xlabel('Aces')
plt.ylabel('Ranking')
plt.title('Visualization of raw data')
# Out:
# Text(0.5, 1.0, 'Visualization of raw data')

# %% [markdown]
# ## Standardization

# %%
scaler = StandardScaler()
players_2019_std = scaler.fit_transform(numerical_data)

# %% [markdown]
# ## ${\textbf{Hierarchical Clustering}}$

# %%
# Perform Hierarchical Clustering. The results are returned as a linkage matrix. 
hier_clust = linkage(players_2019_std, method = 'ward')

# %%
# We plot the results from the Hierarchical Clustering using a Dendrogram. 
# We truncate the dendrogram for better readability. The level p shows only the last p merged clusters
# We also omit showing the labels for each point.
plt.figure(figsize = (12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5, 
           show_leaf_counts = False, 
           no_labels = True)
plt.show()

# %% [markdown]
# ## ${\textbf{K-means Clustering}}$

# %%
# Perform K-means clustering. We consider 1 to 10 clusters, so our for loop runs 10 iterations.
# In addition we run the algortihm at many different starting points - k means plus plus. 
# And we set a random state for reproducibility.
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 1)
    kmeans.fit(players_2019_std)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot we choose the number of clusters. 
# We look for a kink in the graphic, after which the descent of wcss isn't as pronounced.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %%
# We run K-means with a fixed number of clusters. In our case 4.
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 1)

# %%
# We divide our data into the four clusters.
kmeans.fit(players_2019_std)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ## Results

# %%
# We create a new data frame with the original features and add a new column with the assigned clusters for each point.
df_players_2019_kmeans = df_players_2019.copy()
df_players_2019_kmeans['Segment K-means'] = kmeans.labels_

# %%
# Calculate mean values for the clusters
df_players_2019_analysis = df_players_2019_kmeans.groupby(['Segment K-means']).mean()
df_players_2019_analysis
# Out:
#                    Ranking        Age       Points  Tourn Played        Aces  \
# Segment K-means
# 0                51.245283  26.924528  1085.018868     25.924528  280.037736
# 1                11.000000  28.117647  3901.294118     23.058824  369.529412
# 2                45.300000  32.000000  1235.200000     19.900000  626.400000
# 3                84.700000  24.750000   659.950000     24.600000   65.200000
#
#                  Double Faults  1st Serve %  1st Serve Points Won %  \
# Segment K-means
# 0                   133.679245    61.830189               71.830189
# 1                   186.647059    62.941176               73.352941
# 2                   111.800000    63.200000               80.200000
# 3                    44.300000    63.350000               68.000000
#
#                  2nd Serve Points Won %  Break Points Faced  ...  \
# Segment K-means                                              ...
# 0                             51.150943          300.698113  ...
# 1                             52.705882          357.588235  ...
# 2                             53.200000          173.500000  ...
# 3                             49.200000          126.750000  ...
#
#                  Total Service Points Won %  1st Serve Return Points Won %  \
# Segment K-means
# 0                                 63.924528                      27.905660
# 1                                 65.588235                      31.176471
# 2                                 70.100000                      24.700000
# 3                                 61.000000                      28.550000
#
#                  2nd Serve Return Points Won %  Break Points Opportunities  \
# Segment K-means
# 0                                    48.830189                  297.150943
# 1                                    52.352941                  492.294118
# 2                                    43.900000                  200.600000
# 3                                    50.050000                  112.500000
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# 0                               38.622642           568.867925
# 1                               41.058824           774.529412
# 2                               33.900000           511.300000
# 3                               41.100000           202.450000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# 0                         20.150943            35.886792           49.924528
# 1                         26.176471            39.294118           52.235294
# 2                         13.400000            31.600000           50.800000
# 3                         21.200000            36.700000           48.800000
#
#                  Career Length
# Segment K-means
# 0                     9.037736
# 1                    10.882353
# 2                    13.100000
# 3                     6.750000
#
# [4 rows x 23 columns]

# %%
# Compute the size and proportions of the two clusters
df_players_2019_analysis['N Obs'] = df_players_2019_kmeans[['Segment K-means','Ranking']].groupby(['Segment K-means']).count()
df_players_2019_analysis['Prop Obs'] = df_players_2019_analysis['N Obs'] / df_players_2019_analysis['N Obs'].sum()

# %%
df_players_2019_analysis
# Out:
#                    Ranking        Age       Points  Tourn Played        Aces  \
# Segment K-means
# 0                51.245283  26.924528  1085.018868     25.924528  280.037736
# 1                11.000000  28.117647  3901.294118     23.058824  369.529412
# 2                45.300000  32.000000  1235.200000     19.900000  626.400000
# 3                84.700000  24.750000   659.950000     24.600000   65.200000
#
#                  Double Faults  1st Serve %  1st Serve Points Won %  \
# Segment K-means
# 0                   133.679245    61.830189               71.830189
# 1                   186.647059    62.941176               73.352941
# 2                   111.800000    63.200000               80.200000
# 3                    44.300000    63.350000               68.000000
#
#                  2nd Serve Points Won %  Break Points Faced  ...  \
# Segment K-means                                              ...
# 0                             51.150943          300.698113  ...
# 1                             52.705882          357.588235  ...
# 2                             53.200000          173.500000  ...
# 3                             49.200000          126.750000  ...
#
#                  2nd Serve Return Points Won %  Break Points Opportunities  \
# Segment K-means
# 0                                    48.830189                  297.150943
# 1                                    52.352941                  492.294118
# 2                                    43.900000                  200.600000
# 3                                    50.050000                  112.500000
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# 0                               38.622642           568.867925
# 1                               41.058824           774.529412
# 2                               33.900000           511.300000
# 3                               41.100000           202.450000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# 0                         20.150943            35.886792           49.924528
# 1                         26.176471            39.294118           52.235294
# 2                         13.400000            31.600000           50.800000
# 3                         21.200000            36.700000           48.800000
#
#                  Career Length  N Obs  Prop Obs
# Segment K-means
# 0                     9.037736     53      0.53
# 1                    10.882353     17      0.17
# 2                    13.100000     10      0.10
# 3                     6.750000     20      0.20
#
# [4 rows x 25 columns]

# %%
df_players_2019_analysis.rename({0:'Average-Players',
                                 1:'Top-Players',
                                 2:'Good-Players',
                                 3:'Worst-Players'
                                 })
# Out:
#                    Ranking        Age       Points  Tourn Played        Aces  \
# Segment K-means
# Average-Players  51.245283  26.924528  1085.018868     25.924528  280.037736
# Top-Players      11.000000  28.117647  3901.294118     23.058824  369.529412
# Good-Players     45.300000  32.000000  1235.200000     19.900000  626.400000
# Worst-Players    84.700000  24.750000   659.950000     24.600000   65.200000
#
#                  Double Faults  1st Serve %  1st Serve Points Won %  \
# Segment K-means
# Average-Players     133.679245    61.830189               71.830189
# Top-Players         186.647059    62.941176               73.352941
# Good-Players        111.800000    63.200000               80.200000
# Worst-Players        44.300000    63.350000               68.000000
#
#                  2nd Serve Points Won %  Break Points Faced  ...  \
# Segment K-means                                              ...
# Average-Players               51.150943          300.698113  ...
# Top-Players                   52.705882          357.588235  ...
# Good-Players                  53.200000          173.500000  ...
# Worst-Players                 49.200000          126.750000  ...
#
#                  2nd Serve Return Points Won %  Break Points Opportunities  \
# Segment K-means
# Average-Players                      48.830189                  297.150943
# Top-Players                          52.352941                  492.294118
# Good-Players                         43.900000                  200.600000
# Worst-Players                        50.050000                  112.500000
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# Average-Players                 38.622642           568.867925
# Top-Players                     41.058824           774.529412
# Good-Players                    33.900000           511.300000
# Worst-Players                   41.100000           202.450000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# Average-Players           20.150943            35.886792           49.924528
# Top-Players               26.176471            39.294118           52.235294
# Good-Players              13.400000            31.600000           50.800000
# Worst-Players             21.200000            36.700000           48.800000
#
#                  Career Length  N Obs  Prop Obs
# Segment K-means
# Average-Players       9.037736     53      0.53
# Top-Players          10.882353     17      0.17
# Good-Players         13.100000     10      0.10
# Worst-Players         6.750000     20      0.20
#
# [4 rows x 25 columns]

# %%
# Add the segment labels to our table
df_players_2019_kmeans['Labels'] = df_players_2019_kmeans['Segment K-means'].map({0:'Average-Players',
                                                                                 1:'Top-Players',
                                                                                 2:'Good-Players',
                                                                                 3:'Worst-Players'
                                                                                 })

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by  "Aces"

# %%
# We plot the results from the K-means algorithm. 
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2019_kmeans['Aces']
y_axis = df_players_2019_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2019_kmeans['Labels'], palette = ['g', 'r', 'k', 'm'])
plt.title('ATP Top 100 players 2019 K-means')
plt.show() 

#according to correlation map, these are the variables that have the highest impact on ranking 
#'Service Games Played'
#'Return Games Played'
#'Total Points Won %'
##SO, overall, experience is most valuable, it might explain the next gen tournement founded at 2017
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by "Break Points Opportunities"

# %%
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2019_kmeans['Break Points Opportunities']
y_axis = df_players_2019_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2019_kmeans['Labels'], palette = ['g', 'r', 'k', 'm'])
plt.title('ATP Top 100 players 2019 K-means')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by "Return Games Won"

# %%
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2019_kmeans['Return Games Won %']
y_axis = df_players_2019_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2019_kmeans['Labels'], palette = ['g', 'r', 'k', 'm'])
plt.title('ATP Top 100 players 2019 K-means')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## PCA Analysis

# %%
# Employ PCA to find a subset of components, which explain the variance in the data.
pca = PCA()

# %%
# Fit PCA with our standardized data.
pca.fit(players_2019_std)
# Out:
# PCA()

# %%
# The attribute shows how much variance is explained by each of the seven individual components.
pca.explained_variance_ratio_
# Out:
# array([3.43231308e-01, 2.56305316e-01, 1.19325456e-01, 7.80840068e-02,
#        5.20146367e-02, 3.50815764e-02, 2.77128817e-02, 1.91394495e-02,
#        1.79954156e-02, 1.37055827e-02, 9.85500305e-03, 8.14762883e-03,
#        6.36197730e-03, 5.47930435e-03, 1.96303841e-03, 1.57660919e-03,
#        1.32183146e-03, 7.42393541e-04, 6.63132703e-04, 6.08667551e-04,
#        3.65728326e-04, 3.05634780e-04, 1.34213228e-05])

# %%
# Plot the cumulative variance explained by total number of components.
# On this graph we choose the subset of components we want to keep. 
# Generally, we want to keep around 80 % of the explained variance.
plt.figure(figsize = (12,9))
plt.plot(range(1,24), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
# We choose three components. 5 seems the right choice according to the previous graph, due to it allows to preserve 
#around 85% of the data with only 1/5 of the variables.
pca = PCA(n_components = 5)

# %%
#Fit the model the our data with the selected number of components. In our case three.
pca.fit(players_2019_std)
# Out:
# PCA(n_components=5)

# %% [markdown]
# ### ${\textbf{PCA Results}}$

# %%
# Here we discucss the results from the PCA.
# The components attribute shows the loadings of each component on each of the seven original features.
# The loadings are the correlations between the components and the original features. 
pca.components_
# Out:
# array([[ 0.30567092, -0.11062828, -0.24978953,  0.09568584, -0.25220362,
#         -0.20898914,  0.00196789, -0.21879676, -0.20269741, -0.20859493,
#         -0.22499984, -0.31517858, -0.26492902, -0.25646706, -0.04952873,
#         -0.03777953, -0.28806489,  0.0477649 , -0.31341821, -0.05404191,
#         -0.04466443, -0.29919319, -0.12364276],
#        [ 0.09775892,  0.05945206, -0.11844464, -0.10223844,  0.19667706,
#         -0.06990221, -0.05634595,  0.27445165,  0.05675197, -0.20036236,
#          0.20273188, -0.08894912,  0.24452339,  0.24480996, -0.35506758,
#         -0.3348756 , -0.20996757, -0.19742658, -0.09054597, -0.38243236,
#         -0.38355959, -0.07170544,  0.01635306],
#        [ 0.07230367,  0.20289096,  0.1885039 , -0.40397415, -0.18090023,
#         -0.35625171,  0.16876276,  0.00401554,  0.30896932, -0.31420676,
#          0.10974189, -0.21190011,  0.11736905,  0.15153756,  0.10990265,
#          0.1684296 , -0.13213418,  0.18048738, -0.21701045,  0.15153154,
#          0.13318078,  0.23876536,  0.20877216],
#        [ 0.11168355,  0.63659263, -0.14658194,  0.08552581, -0.07445867,
#          0.04981644, -0.21590221, -0.0381871 , -0.11203283,  0.12617213,
#          0.01923983,  0.00543338, -0.07490669, -0.1221234 ,  0.04154101,
#         -0.01913795,  0.03986017, -0.16265417,  0.01212015, -0.03184304,
#          0.0259313 , -0.11984864,  0.63375718],
#        [-0.01688794, -0.03964891,  0.09365264, -0.10510885,  0.04861647,
#          0.25620084, -0.70063598,  0.31895103, -0.20190689, -0.18436423,
#         -0.16924418, -0.11893317,  0.04765727,  0.03629299,  0.1194232 ,
#         -0.02087129, -0.0805183 ,  0.3759438 , -0.12044707,  0.05190881,
#          0.07012545,  0.1073924 , -0.02000691]])

# %%
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = numerical_data.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5'])
df_pca_comp
# Out:
#               Ranking       Age    Points  Tourn Played      Aces  \
# Component 1  0.305671 -0.110628 -0.249790      0.095686 -0.252204
# Component 2  0.097759  0.059452 -0.118445     -0.102238  0.196677
# Component 3  0.072304  0.202891  0.188504     -0.403974 -0.180900
# Component 4  0.111684  0.636593 -0.146582      0.085526 -0.074459
# Component 5 -0.016888 -0.039649  0.093653     -0.105109  0.048616
#
#              Double Faults  1st Serve %  1st Serve Points Won %  \
# Component 1      -0.208989     0.001968               -0.218797
# Component 2      -0.069902    -0.056346                0.274452
# Component 3      -0.356252     0.168763                0.004016
# Component 4       0.049816    -0.215902               -0.038187
# Component 5       0.256201    -0.700636                0.318951
#
#              2nd Serve Points Won %  Break Points Faced  ...  \
# Component 1               -0.202697           -0.208595  ...
# Component 2                0.056752           -0.200362  ...
# Component 3                0.308969           -0.314207  ...
# Component 4               -0.112033            0.126172  ...
# Component 5               -0.201907           -0.184364  ...
#
#              Total Service Points Won %  1st Serve Return Points Won %  \
# Component 1                   -0.256467                      -0.049529
# Component 2                    0.244810                      -0.355068
# Component 3                    0.151538                       0.109903
# Component 4                   -0.122123                       0.041541
# Component 5                    0.036293                       0.119423
#
#              2nd Serve Return Points Won %  Break Points Opportunities  \
# Component 1                      -0.037780                   -0.288065
# Component 2                      -0.334876                   -0.209968
# Component 3                       0.168430                   -0.132134
# Component 4                      -0.019138                    0.039860
# Component 5                      -0.020871                   -0.080518
#
#              Break Points Converted %  Return Games Played  \
# Component 1                  0.047765            -0.313418
# Component 2                 -0.197427            -0.090546
# Component 3                  0.180487            -0.217010
# Component 4                 -0.162654             0.012120
# Component 5                  0.375944            -0.120447
#
#              Return Games Won %  Return Points Won %  Total Points Won %  \
# Component 1           -0.054042            -0.044664           -0.299193
# Component 2           -0.382432            -0.383560           -0.071705
# Component 3            0.151532             0.133181            0.238765
# Component 4           -0.031843             0.025931           -0.119849
# Component 5            0.051909             0.070125            0.107392
#
#              Career Length
# Component 1      -0.123643
# Component 2       0.016353
# Component 3       0.208772
# Component 4       0.633757
# Component 5      -0.020007
#
# [5 rows x 23 columns]

# %%
# Heat Map for Principal Components against original features. Again we use the RdBu color scheme and set borders to -1 and 1.
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu')
plt.yticks([0, 1, 2, 3 ,4], 
           ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5'],
           rotation = 45,
           fontsize = 9)
# Out:
# ([<matplotlib.axis.YTick at 0x22c33414c88>,
#   <matplotlib.axis.YTick at 0x22c330abdc8>,
#   <matplotlib.axis.YTick at 0x22c33586608>,
#   <matplotlib.axis.YTick at 0x22c34764188>,
#   <matplotlib.axis.YTick at 0x22c34764e08>],
#  [Text(0, 0, 'Component 1'),
#   Text(0, 1, 'Component 2'),
#   Text(0, 2, 'Component 3'),
#   Text(0, 3, 'Component 4'),
#   Text(0, 4, 'Component 5')])

# %%
##we had the loadings (correlation of between each original variable and a component) mapped before, but we'll now reduce
##the dimensionality to 5 components to make it more manageable

pca.transform(players_2019_std)
# Out:
# array([[-6.95188512e+00, -3.56070292e+00,  5.83895645e+00,
#         -6.71191259e-01,  8.42875559e-01],
#        [-6.41249792e+00, -3.51112814e+00,  4.32598417e+00,
#         -8.63798003e-01,  1.12643790e+00],
#        [-6.89737463e+00, -2.15014598e-01,  4.41548675e+00,
#          7.80021151e-01, -4.26427223e-02],
#        [-3.80887998e+00, -1.39745066e+00,  7.66729908e-01,
#         -1.49504137e+00, -6.51899972e-01],
#        [-5.68141029e+00, -3.13751458e+00, -6.33506338e-01,
#         -1.96370817e+00,  1.33703942e+00],
#        [-4.96922056e+00, -4.54704660e-01, -2.09891038e+00,
#         -2.19930561e+00, -7.86467099e-01],
#        [-3.77215187e+00, -2.72179653e+00, -3.30003062e+00,
#         -1.16208385e+00,  5.69680049e-01],
#        [-3.67988567e+00,  1.52266088e+00, -1.31133040e+00,
#         -1.70877717e+00, -1.22295340e-01],
#        [-3.22562757e+00, -1.73664076e+00,  1.41111950e+00,
#          2.05229820e-01, -1.02566784e+00],
#        [-3.09171956e+00, -2.16716614e+00,  4.53109083e-01,
#          1.07565714e+00,  7.68989454e-02],
#        [-1.86391093e+00, -3.29221533e+00, -9.85087731e-01,
#          5.16659876e-01,  1.21856021e+00],
#        [-8.04604682e-01, -3.22469294e+00, -7.49347772e-01,
#          1.76874032e+00,  8.87348935e-01],
#        [-1.74359472e+00, -3.14015235e+00,  2.36545782e+00,
#          8.26161318e-02,  1.91622122e-01],
#        [-2.12726645e+00, -5.45115924e+00, -3.35471655e-01,
#          7.64838406e-04, -5.89699246e-01],
#        [-2.29267086e+00,  4.89819777e-01, -1.88889368e+00,
#         -1.94669506e+00,  9.06333424e-01],
#        [-3.55812525e+00,  1.76915275e+00,  8.62077198e-01,
#          1.47685929e+00, -3.64864408e-02],
#        [-1.70487768e+00, -1.76405128e-01, -1.49711360e+00,
#         -9.82105652e-01, -1.94949444e-01],
#        [-1.82034300e+00, -1.04863840e+00,  2.54520414e-01,
#         -2.14867597e+00,  7.54892906e-01],
#        [-4.00265008e+00,  7.11431598e+00,  1.02737835e+00,
#         -5.58819780e-01, -2.57969854e+00],
#        [-1.57655125e+00, -5.79766666e-01,  6.13549252e-02,
#          1.78687652e-02,  5.69432191e-01],
#        [-1.46939875e+00,  2.44795978e-01, -1.94231441e+00,
#         -2.27578356e+00,  2.71860051e-01],
#        [-7.48109282e-01,  1.36786532e+00, -8.07739851e-01,
#         -5.40672190e-01,  3.77668733e-01],
#        [-1.61742905e+00, -1.86391499e+00, -6.63250478e-01,
#         -1.10051914e+00,  8.68017063e-01],
#        [-2.75811981e+00, -1.56560144e+00, -4.73390111e+00,
#          2.15288415e+00,  2.96306457e+00],
#        [-1.92355896e+00, -2.18170148e+00, -6.53262496e-01,
#          6.70688859e-01, -2.01039166e+00],
#        [-1.26341463e+00, -2.33005954e+00, -2.06005688e+00,
#          8.80283259e-01,  1.11361801e+00],
#        [-1.80219581e+00, -4.30424696e-01,  7.90139015e-01,
#         -3.26025100e-01, -2.03723926e+00],
#        [-1.45369086e+00,  5.73266666e-01, -3.62061047e-01,
#         -1.22220812e+00, -3.98575573e-01],
#        [-2.63324023e+00,  2.08009312e+00,  6.68448682e-01,
#          9.97932317e-01,  7.81005572e-01],
#        [-6.58122309e-01,  4.91095956e+00,  3.21506360e-02,
#         -2.05570133e+00,  2.60623073e-01],
#        [-3.32239962e+00,  4.79470157e+00,  1.86077084e+00,
#         -7.91786419e-01,  3.10050550e-01],
#        [-1.03213737e+00,  2.11850504e+00, -2.63478388e+00,
#         -1.12559303e+00,  1.65864436e-01],
#        [-5.65588687e-01, -1.02815215e+00, -1.11272315e+00,
#         -3.36379523e-01, -1.66591884e-01],
#        [ 5.11623351e-01, -1.83219782e+00,  1.07677571e-01,
#          3.96220405e-01, -1.78579615e+00],
#        [-2.89061495e+00,  9.10826048e-01, -1.46700386e+00,
#          4.79081063e-01,  1.34336245e+00],
#        [-2.41811917e+00,  6.54069449e+00, -2.06278812e+00,
#         -2.10508610e+00, -8.48253623e-01],
#        [-5.97653052e-01,  9.58342542e-01, -1.25739305e+00,
#         -1.48247847e+00, -8.71558848e-01],
#        [ 8.80571773e-01, -4.21575668e-01, -1.10489428e+00,
#         -3.33656630e-01, -2.00090922e-02],
#        [-1.41174821e+00,  1.24948279e+00, -4.15848737e-01,
#          1.38773335e+00,  1.29567487e+00],
#        [-6.20632816e-01, -2.01559530e+00,  1.42689140e+00,
#         -1.92603957e-01, -6.97499957e-01],
#        [-1.53739665e-01, -1.85015739e+00, -1.34300493e-01,
#          9.97336820e-01, -6.08958291e-01],
#        [-3.03703417e-03, -9.28747601e-01,  6.99396599e-01,
#          8.12781310e-01, -4.43512332e-01],
#        [-4.93107460e-01, -1.73314745e+00, -2.25169253e-01,
#          1.44327503e+00,  3.86812831e-01],
#        [-1.65550500e+00,  3.49721093e+00,  1.20402717e-01,
#          7.09199257e-01,  8.83862863e-01],
#        [-1.73335183e-01, -3.93406443e-01,  6.79877542e-02,
#          1.63315193e+00,  9.71874793e-01],
#        [-4.20493176e-01, -1.86313120e+00, -7.99624642e-01,
#          9.20321427e-01, -1.29827485e+00],
#        [ 3.78864684e-01, -1.96619231e-01, -1.53476354e+00,
#         -1.41743597e+00, -1.18829741e+00],
#        [-6.96715467e-02, -6.87269654e-01,  9.71902656e-03,
#          1.03776206e+00, -6.13347501e-01],
#        [-2.05590985e+00, -5.67496995e-01, -9.33456305e-01,
#          2.66304994e+00, -1.05069073e+00],
#        [-3.29538050e-01, -4.81792267e-03,  1.53044278e-01,
#         -2.90436905e-02, -4.85399261e-01],
#        [-1.77649397e+00,  8.72784077e-01, -1.92679046e+00,
#          1.58188295e+00, -2.30671560e-01],
#        [ 3.26410015e-01,  2.01303329e+00, -9.97340841e-01,
#         -6.66650280e-01, -7.86065310e-01],
#        [ 1.31892540e+00, -8.74379396e-01, -1.70414776e+00,
#         -8.91632000e-01, -1.02827652e+00],
#        [ 1.15011136e+00, -3.43984097e-01,  1.39647454e-01,
#         -1.72069874e+00, -2.55991444e-01],
#        [-8.21139233e-01, -2.34068886e+00, -4.59167005e-01,
#          2.71118670e+00, -7.39527790e-01],
#        [ 1.80734443e+00,  1.23879932e+00, -2.62886941e+00,
#         -7.96650271e-01,  2.11862429e+00],
#        [ 3.61573241e-01,  6.77061203e-01, -1.38506030e+00,
#         -1.33588419e+00,  3.45205914e-01],
#        [ 5.41701116e-01,  7.13171821e-01,  3.60717937e-01,
#          7.62679590e-01,  1.53302418e+00],
#        [ 3.46078231e-01,  5.93022980e-01, -2.37852280e-01,
#         -1.84941824e+00, -3.72336597e-01],
#        [ 1.11854745e-01,  8.18899780e-04, -1.80763944e+00,
#          1.28342696e+00, -9.22474607e-01],
#        [ 7.35467324e-01,  1.45050962e+00,  4.97940534e-01,
#          2.19371768e+00, -1.03844423e-01],
#        [-4.76720037e-01,  4.71929377e+00,  1.15294150e+00,
#          3.28684105e+00,  5.65757266e-01],
#        [-3.90243660e-01, -2.43685279e-01,  1.41528803e-01,
#         -1.02717213e+00, -1.04340359e+00],
#        [ 2.66542200e+00, -1.69367349e+00,  5.95490735e-01,
#          2.10883890e+00, -8.09778187e-02],
#        [ 2.68591459e-01,  1.32629671e+00, -1.13830444e+00,
#          5.18339126e-01, -3.19419697e-01],
#        [ 3.36452706e+00,  6.57029773e-01,  9.18873864e-01,
#          1.15736386e+00,  4.23862861e-01],
#        [ 1.27695155e+00, -2.68572488e-01,  7.54688882e-02,
#          1.42537837e+00, -2.30588219e+00],
#        [ 1.63008588e+00,  1.26995566e+00, -3.82193923e-01,
#          2.98077284e-01,  4.54214835e-01],
#        [ 1.83166412e+00,  1.06640980e+00,  1.20289371e-01,
#         -6.74535823e-01,  1.96691519e-02],
#        [ 3.81686978e-01, -2.28432285e+00, -1.42923077e+00,
#          1.04123286e+00,  6.89619714e-01],
#        [ 2.49512521e+00,  3.08307717e-01, -1.15196103e+00,
#          4.58141407e-01, -6.59247427e-01],
#        [ 8.83614757e-01, -2.37248319e-01, -7.09722588e-01,
#          2.77581261e+00,  5.13611956e-01],
#        [ 1.90452874e+00, -2.67073059e+00,  1.02434164e+00,
#         -8.60593562e-01, -1.85062330e+00],
#        [ 5.08630133e+00, -2.82919380e+00,  2.46170937e+00,
#         -1.73208163e+00, -2.66312885e-01],
#        [ 3.56347970e+00, -2.83918303e+00,  4.92782172e-01,
#          3.47056832e-01, -2.83873519e+00],
#        [ 1.92017631e+00, -1.82852391e+00, -1.05862449e-01,
#          1.18490401e+00,  1.04360685e-02],
#        [ 1.23186343e+00,  2.06551255e+00, -7.23185870e-02,
#         -1.01764346e+00,  4.67119981e-03],
#        [ 3.07887525e+00, -4.13324703e-01,  9.79405754e-01,
#         -1.95675708e+00,  8.85113035e-01],
#        [ 3.81538586e-01,  9.63183477e-01,  1.32708519e+00,
#          2.48506643e+00, -6.75535979e-01],
#        [ 1.85224101e+00, -2.86395129e+00, -5.66819798e-01,
#          3.31721262e-01,  3.42448174e-01],
#        [ 2.39431520e+00,  1.86209326e+00,  4.12651884e+00,
#         -1.46037890e+00,  2.62412514e+00],
#        [ 3.96484097e+00, -2.44032681e-01,  1.11575331e+00,
#         -3.30055701e-01,  7.00403197e-01],
#        [ 5.57798179e+00, -2.83388477e+00, -2.58112912e-01,
#         -1.19516430e+00, -3.57131856e-02],
#        [ 3.14506239e+00,  1.19954187e+00,  1.06046843e+00,
#          7.86766772e-01,  3.19275238e+00],
#        [ 1.31404874e+00,  1.55872091e+00,  1.99780424e-01,
#          2.17085690e-01,  8.53045908e-01],
#        [ 2.10599445e+00, -1.67024223e+00, -1.27396638e+00,
#         -4.15057402e-01, -2.95961400e-01],
#        [ 6.38898932e+00, -1.97612816e+00,  2.89581189e-01,
#         -1.64270163e+00, -5.03246998e-01],
#        [ 3.75866548e+00,  3.84658105e-01,  1.03049766e+00,
#         -8.62524950e-01, -4.40144178e-01],
#        [ 5.34534038e+00,  1.26174513e+00, -4.99279544e-01,
#          2.98686920e-01, -8.44666767e-01],
#        [ 3.68965525e+00,  1.46607239e-01,  3.75071505e+00,
#         -2.05767891e+00,  1.28892119e+00],
#        [ 6.69708012e-02,  3.63147569e+00,  4.06547278e+00,
#          3.75054735e-01,  3.57905682e-01],
#        [ 1.40265162e-01,  2.23391490e+00,  2.82611592e-01,
#          1.88098498e+00,  7.98953320e-01],
#        [ 3.38901296e+00, -1.78023908e+00, -8.99100004e-01,
#          9.32930766e-01, -1.27121057e+00],
#        [ 4.35823466e+00,  5.03809678e-01,  8.34553998e-01,
#         -4.83663001e-01,  1.19704359e+00],
#        [-1.00484929e+00,  9.62498587e+00,  9.14838321e-01,
#          2.17869040e+00, -1.44349233e+00],
#        [ 5.05098533e+00, -3.60488043e+00,  2.40990364e+00,
#         -4.66605086e-02, -7.16948635e-01],
#        [ 1.87724984e+00,  3.13438143e+00, -1.37575220e+00,
#         -1.27584744e+00, -3.68886104e-01],
#        [ 2.46130878e+00,  2.79359770e+00,  1.89967899e+00,
#         -2.43112718e-01, -1.42723246e+00],
#        [ 4.47025731e+00,  1.41248661e+00, -7.18157353e-01,
#         -9.07654204e-01,  1.02922910e+00],
#        [ 7.20882695e+00,  1.72413296e+00, -5.54723286e-01,
#          7.57405572e-01,  1.95791233e+00]])

# %%
scores_pca = pca.transform(players_2019_std)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA}}$

# %%
# We fit K means using the transformed data from the PCA.
wcss = []
##within clusters sum of squares (wcss)
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 1)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
# Plot the Within Cluster Sum of Squares for the K-means PCA model. Here we make a decission about the number of clusters.
# Again it looks like four is the best option.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
# We have chosen four clusters, so we run K-means with number of clusters equals four. 
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state =1)

# %%
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA Results}}$

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters.
df_players_2019_pca_kmeans = pd.concat([df_players_2019.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
df_players_2019_pca_kmeans.columns.values[-5: ] = ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5']
# The last column we add contains the pca k-means clustering labels.
df_players_2019_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

# %%
df_players_2019_pca_kmeans
# Out:
#     Ranking            Player  Age  Points  Tourn Played  Aces  Double Faults  \
# 0         1      Rafael Nadal   33    9985            17   271            118
# 1         2    Novak Djokovic   32    9145            17   373            166
# 2         3     Roger Federer   38    6590            17   481            100
# 3         4     Dominic Thiem   26    5825            22   314            138
# 4         5   Daniil Medvedev   23    5705            24   690            254
# ..      ...               ...  ...     ...           ...   ...            ...
# 95       96  Salvatore Caruso   27     586            28    11             17
# 96       97    Alexei Popyrin   20     585            25   248            121
# 97       98    Egor Gerasimov   27     581            23   130             38
# 98       99      Lloyd Harris   22     576            24   200             57
# 99      100   James Duckworth   27     576            28    26             15
#
#     1st Serve %  1st Serve Points Won %  2nd Serve Points Won %  ...  \
# 0            65                      76                      60  ...
# 1            66                      76                      57  ...
# 2            65                      78                      59  ...
# 3            66                      73                      55  ...
# 4            60                      76                      55  ...
# ..          ...                     ...                     ...  ...
# 95           69                      62                      49  ...
# 96           61                      73                      51  ...
# 97           67                      74                      53  ...
# 98           62                      72                      44  ...
# 99           59                      69                      43  ...
#
#     Return Games Won %  Return Points Won %  Total Points Won %  \
# 0                   35                   42                  56
# 1                   32                   42                  55
# 2                   25                   39                  55
# 3                   23                   37                  52
# 4                   28                   40                  53
# ..                 ...                  ...                 ...
# 95                  31                   41                  49
# 96                  14                   32                  49
# 97                  13                   35                  50
# 98                  18                   33                  48
# 99                  13                   32                  46
#
#     Career Length  Component 1  Component 2  Component 3  Component 4  \
# 0              18    -6.951885    -3.560703     5.838956    -0.671191
# 1              16    -6.412498    -3.511128     4.325984    -0.863798
# 2              21    -6.897375    -0.215015     4.415487     0.780021
# 3               8    -3.808880    -1.397451     0.766730    -1.495041
# 4               5    -5.681410    -3.137515    -0.633506    -1.963708
# ..            ...          ...          ...          ...          ...
# 95              9     5.050985    -3.604880     2.409904    -0.046661
# 96              2     1.877250     3.134381    -1.375752    -1.275847
# 97              9     2.461309     2.793598     1.899679    -0.243113
# 98              4     4.470257     1.412487    -0.718157    -0.907654
# 99              9     7.208827     1.724133    -0.554723     0.757406
#
#     Component 5  Segment K-means PCA
# 0      0.842876                    2
# 1      1.126438                    2
# 2     -0.042643                    2
# 3     -0.651900                    2
# 4      1.337039                    2
# ..          ...                  ...
# 95    -0.716949                    0
# 96    -0.368886                    0
# 97    -1.427232                    0
# 98     1.029229                    0
# 99     1.957912                    0
#
# [100 rows x 30 columns]

# %%
# We calculate the means by segments.
df_players_2019_pca_kmeans_freq = df_players_2019_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_players_2019_pca_kmeans_freq
# Out:
#                        Ranking        Age       Points  Tourn Played  \
# Segment K-means PCA
# 0                    81.900000  24.866667   682.400000     25.100000
# 1                    42.163265  27.306122  1250.714286     25.959184
# 2                     6.727273  28.727273  5024.545455     21.181818
# 3                    45.300000  32.000000  1235.200000     19.900000
#
#                            Aces  Double Faults  1st Serve %  \
# Segment K-means PCA
# 0                    109.166667      64.833333    62.933333
# 1                    303.755102     147.591837    61.489796
# 2                    388.090909     178.818182    64.818182
# 3                    626.400000     111.800000    63.200000
#
#                      1st Serve Points Won %  2nd Serve Points Won %  \
# Segment K-means PCA
# 0                                 68.833333               49.600000
# 1                                 72.183673               51.224490
# 2                                 73.818182               53.909091
# 3                                 80.200000               53.200000
#
#                      Break Points Faced  ...  Return Games Played  \
# Segment K-means PCA                      ...
# 0                            165.600000  ...           283.166667
# 1                            321.918367  ...           611.591837
# 2                            346.272727  ...           809.363636
# 3                            173.500000  ...           511.300000
#
#                      Return Games Won %  Return Points Won %  \
# Segment K-means PCA
# 0                             20.700000            36.266667
# 1                             20.775510            36.326531
# 2                             27.090909            39.636364
# 3                             13.400000            31.600000
#
#                      Total Points Won %  Career Length  Component 1  \
# Segment K-means PCA
# 0                             48.966667       6.733333     3.275839
# 1                             50.183673       9.591837    -0.610832
# 2                             52.909091      11.545455    -4.425603
# 3                             50.800000      13.100000    -1.966276
#
#                      Component 2  Component 3  Component 4  Component 5
# Segment K-means PCA
# 0                      -0.208099     0.519725    -0.333461     0.104265
# 1                      -0.305030    -0.764130     0.259214    -0.049539
# 2                      -2.499403     1.200811    -0.564622     0.095289
# 3                       4.868288     0.864169     0.351318    -0.174873
#
# [4 rows x 28 columns]

# %%
# Calculate the size of each cluster and its proportion to the entire data set.
df_players_2019_pca_kmeans_freq['N Obs'] = df_players_2019_pca_kmeans[['Segment K-means PCA','Ranking']].groupby(['Segment K-means PCA']).count()
df_players_2019_pca_kmeans_freq['Prop Obs'] = df_players_2019_pca_kmeans_freq['N Obs'] / df_players_2019_pca_kmeans_freq['N Obs'].sum()
df_players_2019_pca_kmeans_freq = df_players_2019_pca_kmeans_freq.rename({0:'Worst-Players', 
                                                          1:'Good-Players',
                                                          2:'Top-Players',
                                                          3: 'Average-Players'})               
df_players_2019_pca_kmeans_freq
# Out:
#                        Ranking        Age       Points  Tourn Played  \
# Segment K-means PCA
# Worst-Players        81.900000  24.866667   682.400000     25.100000
# Good-Players         42.163265  27.306122  1250.714286     25.959184
# Top-Players           6.727273  28.727273  5024.545455     21.181818
# Average-Players      45.300000  32.000000  1235.200000     19.900000
#
#                            Aces  Double Faults  1st Serve %  \
# Segment K-means PCA
# Worst-Players        109.166667      64.833333    62.933333
# Good-Players         303.755102     147.591837    61.489796
# Top-Players          388.090909     178.818182    64.818182
# Average-Players      626.400000     111.800000    63.200000
#
#                      1st Serve Points Won %  2nd Serve Points Won %  \
# Segment K-means PCA
# Worst-Players                     68.833333               49.600000
# Good-Players                      72.183673               51.224490
# Top-Players                       73.818182               53.909091
# Average-Players                   80.200000               53.200000
#
#                      Break Points Faced  ...  Return Points Won %  \
# Segment K-means PCA                      ...
# Worst-Players                165.600000  ...            36.266667
# Good-Players                 321.918367  ...            36.326531
# Top-Players                  346.272727  ...            39.636364
# Average-Players              173.500000  ...            31.600000
#
#                      Total Points Won %  Career Length  Component 1  \
# Segment K-means PCA
# Worst-Players                 48.966667       6.733333     3.275839
# Good-Players                  50.183673       9.591837    -0.610832
# Top-Players                   52.909091      11.545455    -4.425603
# Average-Players               50.800000      13.100000    -1.966276
#
#                      Component 2  Component 3  Component 4  Component 5  \
# Segment K-means PCA
# Worst-Players          -0.208099     0.519725    -0.333461     0.104265
# Good-Players           -0.305030    -0.764130     0.259214    -0.049539
# Top-Players            -2.499403     1.200811    -0.564622     0.095289
# Average-Players         4.868288     0.864169     0.351318    -0.174873
#
#                      N Obs  Prop Obs
# Segment K-means PCA
# Worst-Players           30      0.30
# Good-Players            49      0.49
# Top-Players             11      0.11
# Average-Players         10      0.10
#
# [4 rows x 30 columns]

# %%
df_players_2019_pca_kmeans['Legend'] = df_players_2019_pca_kmeans['Segment K-means PCA'].map({0:'Worst-Players', 
                                                          1:'Good-Players',
                                                          2:'Top-Players',
                                                          3: 'Average-Players'})

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
x_axis = df_players_2019_pca_kmeans['Component 1']
y_axis = df_players_2019_pca_kmeans['Component 2']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2019_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
