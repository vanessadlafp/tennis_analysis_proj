# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import scipy


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#For standardizing features

from sklearn.preprocessing import StandardScaler

#Hierarchical clustering with the Sci Py library. We'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# ## Load the data

# %%
df_players_2011= pd.read_csv("players_2011.csv")

# %% [markdown]
# ## Data exploration

# %% [markdown]
# ### Players' performance 2011

# %%
df_players_2011.head()
# Out:
#    Unnamed: 0  Ranking  Move  Country          Player  Age  Points  \
# 0           0        1   NaN      NaN  Novak Djokovic   24   13630
# 1           1        2   NaN      NaN    Rafael Nadal   25    9595
# 2           2        3   NaN      NaN   Roger Federer   30    8170
# 3           3        4   NaN      NaN     Andy Murray   24    7380
# 4           4        5   NaN      NaN    David Ferrer   29    4925
#
#    Tourn Played  Points Dropping  Next Best  ...  Service Games Won  \
# 0            19                0          0  ...                86%
# 1            20                0          0  ...                83%
# 2            19                0          0  ...                90%
# 3            19                0          0  ...                80%
# 4            23                0          0  ...                83%
#
#    Total Service Points Won  1st Serve Return Points Won  \
# 0                       68%                          36%
# 1                       67%                          34%
# 2                       71%                          33%
# 3                       65%                          37%
# 4                       66%                          33%
#
#    2nd Serve Return Points Won Break Points Opportunities  \
# 0                          58%                        692
# 1                          57%                        706
# 2                          51%                        593
# 3                          56%                        637
# 4                          56%                        627
#
#   Break Points Converted Return Games Played  Return Games Won  \
# 0                    48%                 860               39%
# 1                    46%                 951               34%
# 2                    41%                 877               28%
# 3                    46%                 809               36%
# 4                    46%                 877               33%
#
#   Return Points Won  Total Points Won
# 0               45%               56%
# 1               43%               54%
# 2               40%               55%
# 3               44%               54%
# 4               42%               54%
#
# [5 rows x 30 columns]

# %%
df_players_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   100 non-null    int64
#  1   Ranking                      100 non-null    int64
#  2   Move                         0 non-null      float64
#  3   Country                      0 non-null      float64
#  4   Player                       100 non-null    object
#  5   Age                          100 non-null    int64
#  6   Points                       100 non-null    int64
#  7   Tourn Played                 100 non-null    int64
#  8   Points Dropping              100 non-null    int64
#  9   Next Best                    100 non-null    int64
#  10  Turned Pro                   100 non-null    int64
#  11  index                        100 non-null    int64
#  12  Aces                         100 non-null    int64
#  13  Double Faults                100 non-null    int64
#  14  1st Serve                    100 non-null    object
#  15  1st Serve Points Won         100 non-null    object
#  16  2nd Serve Points Won         100 non-null    object
#  17  Break Points Faced           100 non-null    int64
#  18  Break Points Saved           100 non-null    object
#  19  Service Games Played         100 non-null    int64
#  20  Service Games Won            100 non-null    object
#  21  Total Service Points Won     100 non-null    object
#  22  1st Serve Return Points Won  100 non-null    object
#  23  2nd Serve Return Points Won  100 non-null    object
#  24  Break Points Opportunities   100 non-null    int64
#  25  Break Points Converted       100 non-null    object
#  26  Return Games Played          100 non-null    int64
#  27  Return Games Won             100 non-null    object
#  28  Return Points Won            100 non-null    object
#  29  Total Points Won             100 non-null    object
# dtypes: float64(2), int64(15), object(13)
# memory usage: 23.6+ KB

# %% [markdown]
# We see some columns with  numeric values aren't considered as such due to they have the percentage symbols next to it
# and that columns Move and Country have NaN values

# %%
df_players_2011= df_players_2011.drop(['Unnamed: 0', 'Move', 'Country', 'Points Dropping', 'Next Best','index'], axis=1)
df_players_2011
# Out:
#     Ranking           Player  Age  Points  Tourn Played  Turned Pro  Aces  \
# 0         1   Novak Djokovic   24   13630            19        2003   343
# 1         2     Rafael Nadal   25    9595            20        2001   267
# 2         3    Roger Federer   30    8170            19        1998   504
# 3         4      Andy Murray   24    7380            19        2005   494
# 4         5     David Ferrer   29    4925            23        2000   265
# ..      ...              ...  ...     ...           ...         ...   ...
# 95       96     Tobias Kamke   25     582            33        2004    87
# 96       97      Eric Prodon   30     581            29        2000     7
# 97       98     Andreas Beck   25     580            30        2003     8
# 98       99  Michael Russell   33     577            29        1998    88
# 99      100   Michael Berrer   31     567            26        1999   194
#
#     Double Faults 1st Serve 1st Serve Points Won  ... Service Games Won  \
# 0             143       65%                  74%  ...               86%
# 1             121       68%                  71%  ...               83%
# 2              98       64%                  79%  ...               90%
# 3             149       59%                  75%  ...               80%
# 4             200       61%                  72%  ...               83%
# ..            ...       ...                  ...  ...               ...
# 95            134       57%                  66%  ...               72%
# 96             17       54%                  57%  ...               51%
# 97              4       65%                  63%  ...               76%
# 98            127       64%                  69%  ...               73%
# 99            114       64%                  71%  ...               78%
#
#     Total Service Points Won 1st Serve Return Points Won  \
# 0                        68%                         36%
# 1                        67%                         34%
# 2                        71%                         33%
# 3                        65%                         37%
# 4                        66%                         33%
# ..                       ...                         ...
# 95                       59%                         31%
# 96                       49%                         26%
# 97                       60%                         22%
# 98                       61%                         28%
# 99                       63%                         29%
#
#     2nd Serve Return Points Won Break Points Opportunities  \
# 0                           58%                        692
# 1                           57%                        706
# 2                           51%                        593
# 3                           56%                        637
# 4                           56%                        627
# ..                          ...                        ...
# 95                          51%                        268
# 96                          52%                         22
# 97                          41%                         13
# 98                          48%                        171
# 99                          47%                        225
#
#    Break Points Converted Return Games Played Return Games Won  \
# 0                     48%                 860              39%
# 1                     46%                 951              34%
# 2                     41%                 877              28%
# 3                     46%                 809              36%
# 4                     46%                 877              33%
# ..                    ...                 ...              ...
# 95                    40%                 424              25%
# 96                    32%                  39              18%
# 97                     8%                  50               2%
# 98                    45%                 353              22%
# 99                    36%                 458              17%
#
#     Return Points Won Total Points Won
# 0                 45%              56%
# 1                 43%              54%
# 2                 40%              55%
# 3                 44%              54%
# 4                 42%              54%
# ..                ...              ...
# 95                38%              49%
# 96                35%              42%
# 97                28%              44%
# 98                36%              49%
# 99                35%              49%
#
# [100 rows x 24 columns]

# %%
df_players_2011['1st Serve']= df_players_2011['1st Serve'].apply(lambda x: int(x.strip('%')))
df_players_2011['1st Serve Points Won']= df_players_2011['1st Serve Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['2nd Serve Points Won']= df_players_2011['2nd Serve Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Break Points Saved']= df_players_2011['Break Points Saved'].apply(lambda x: int(x.strip('%')))
df_players_2011['Service Games Won']= df_players_2011['Service Games Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Total Service Points Won']= df_players_2011['Total Service Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['1st Serve Return Points Won']= df_players_2011['1st Serve Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['2nd Serve Return Points Won']= df_players_2011['2nd Serve Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Break Points Converted']= df_players_2011['Break Points Converted'].apply(lambda x: int(x.strip('%')))
df_players_2011['Return Games Won']= df_players_2011['Return Games Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Return Points Won']= df_players_2011['Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Total Points Won']= df_players_2011['Total Points Won'].apply(lambda x: int(x.strip('%')))

df_players_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ranking                      100 non-null    int64
#  1   Player                       100 non-null    object
#  2   Age                          100 non-null    int64
#  3   Points                       100 non-null    int64
#  4   Tourn Played                 100 non-null    int64
#  5   Turned Pro                   100 non-null    int64
#  6   Aces                         100 non-null    int64
#  7   Double Faults                100 non-null    int64
#  8   1st Serve                    100 non-null    int64
#  9   1st Serve Points Won         100 non-null    int64
#  10  2nd Serve Points Won         100 non-null    int64
#  11  Break Points Faced           100 non-null    int64
#  12  Break Points Saved           100 non-null    int64
#  13  Service Games Played         100 non-null    int64
#  14  Service Games Won            100 non-null    int64
#  15  Total Service Points Won     100 non-null    int64
#  16  1st Serve Return Points Won  100 non-null    int64
#  17  2nd Serve Return Points Won  100 non-null    int64
#  18  Break Points Opportunities   100 non-null    int64
#  19  Break Points Converted       100 non-null    int64
#  20  Return Games Played          100 non-null    int64
#  21  Return Games Won             100 non-null    int64
#  22  Return Points Won            100 non-null    int64
#  23  Total Points Won             100 non-null    int64
# dtypes: int64(23), object(1)
# memory usage: 18.9+ KB

# %%
df_players_2011.columns
# Out:
# Index(['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Turned Pro',
#        'Aces', 'Double Faults', '1st Serve', '1st Serve Points Won',
#        '2nd Serve Points Won', 'Break Points Faced', 'Break Points Saved',
#        'Service Games Played', 'Service Games Won', 'Total Service Points Won',
#        '1st Serve Return Points Won', '2nd Serve Return Points Won',
#        'Break Points Opportunities', 'Break Points Converted',
#        'Return Games Played', 'Return Games Won', 'Return Points Won',
#        'Total Points Won'],
#       dtype='object')

# %%
cols= ['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Turned Pro',
       'Aces', 'Double Faults', '1st Serve %', '1st Serve Points Won %',
       '2nd Serve Points Won %', 'Break Points Faced', 'Break Points Saved %',
       'Service Games Played', 'Service Games Won %', 'Total Service Points Won %',
       '1st Serve Return Points Won %', '2nd Serve Return Points Won %',
       'Break Points Opportunities', 'Break Points Converted %',
       'Return Games Played', 'Return Games Won %', 'Return Points Won %',
       'Total Points Won %']


df_players_2011.columns= cols

# %%
df_players_2011
# Out:
#     Ranking           Player  Age  Points  Tourn Played  Turned Pro  Aces  \
# 0         1   Novak Djokovic   24   13630            19        2003   343
# 1         2     Rafael Nadal   25    9595            20        2001   267
# 2         3    Roger Federer   30    8170            19        1998   504
# 3         4      Andy Murray   24    7380            19        2005   494
# 4         5     David Ferrer   29    4925            23        2000   265
# ..      ...              ...  ...     ...           ...         ...   ...
# 95       96     Tobias Kamke   25     582            33        2004    87
# 96       97      Eric Prodon   30     581            29        2000     7
# 97       98     Andreas Beck   25     580            30        2003     8
# 98       99  Michael Russell   33     577            29        1998    88
# 99      100   Michael Berrer   31     567            26        1999   194
#
#     Double Faults  1st Serve %  1st Serve Points Won %  ...  \
# 0             143           65                      74  ...
# 1             121           68                      71  ...
# 2              98           64                      79  ...
# 3             149           59                      75  ...
# 4             200           61                      72  ...
# ..            ...          ...                     ...  ...
# 95            134           57                      66  ...
# 96             17           54                      57  ...
# 97              4           65                      63  ...
# 98            127           64                      69  ...
# 99            114           64                      71  ...
#
#     Service Games Won %  Total Service Points Won %  \
# 0                    86                          68
# 1                    83                          67
# 2                    90                          71
# 3                    80                          65
# 4                    83                          66
# ..                  ...                         ...
# 95                   72                          59
# 96                   51                          49
# 97                   76                          60
# 98                   73                          61
# 99                   78                          63
#
#     1st Serve Return Points Won %  2nd Serve Return Points Won %  \
# 0                              36                             58
# 1                              34                             57
# 2                              33                             51
# 3                              37                             56
# 4                              33                             56
# ..                            ...                            ...
# 95                             31                             51
# 96                             26                             52
# 97                             22                             41
# 98                             28                             48
# 99                             29                             47
#
#     Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 0                          692                        48                  860
# 1                          706                        46                  951
# 2                          593                        41                  877
# 3                          637                        46                  809
# 4                          627                        46                  877
# ..                         ...                       ...                  ...
# 95                         268                        40                  424
# 96                          22                        32                   39
# 97                          13                         8                   50
# 98                         171                        45                  353
# 99                         225                        36                  458
#
#     Return Games Won %  Return Points Won %  Total Points Won %
# 0                   39                   45                  56
# 1                   34                   43                  54
# 2                   28                   40                  55
# 3                   36                   44                  54
# 4                   33                   42                  54
# ..                 ...                  ...                 ...
# 95                  25                   38                  49
# 96                  18                   35                  42
# 97                   2                   28                  44
# 98                  22                   36                  49
# 99                  17                   35                  49
#
# [100 rows x 24 columns]

# %%
df_players_2011['Career Length']= 2011- df_players_2011['Turned Pro']
df_players_2011= df_players_2011.drop(['Turned Pro'], axis=1)
df_players_2011['Career Length']
# Out:
# 0      8
# 1     10
# 2     13
# 3      6
# 4     11
#       ..
# 95     7
# 96    11
# 97     8
# 98    13
# 99    12
# Name: Career Length, Length: 100, dtype: int64

# %%
df_players_2011.describe()
# Out:
#           Ranking         Age        Points  Tourn Played        Aces  \
# count  100.000000  100.000000    100.000000      100.0000  100.000000
# mean    50.500000   26.670000   1488.000000       25.8300  247.020000
# std     29.011492    3.250656   1908.893561        3.3335  187.221037
# min      1.000000   19.000000    567.000000       18.0000    7.000000
# 25%     25.750000   24.000000    668.250000       24.0000  109.000000
# 50%     50.500000   26.500000    907.500000       26.0000  183.000000
# 75%     75.250000   29.250000   1358.750000       28.0000  347.750000
# max    100.000000   33.000000  13630.000000       35.0000  825.000000
#
#        Double Faults  1st Serve %  1st Serve Points Won %  \
# count     100.000000   100.000000              100.000000
# mean      116.280000    61.050000               70.330000
# std        49.167017     4.085884                4.649438
# min         4.000000    51.000000               57.000000
# 25%        78.000000    58.000000               67.000000
# 50%       119.000000    61.000000               70.000000
# 75%       148.250000    64.000000               74.000000
# max       231.000000    71.000000               80.000000
#
#        2nd Serve Points Won %  Break Points Faced  ...  \
# count              100.000000          100.000000  ...
# mean                50.670000          276.850000  ...
# std                  3.055232           96.353031  ...
# min                 39.000000           27.000000  ...
# 25%                 49.000000          224.000000  ...
# 50%                 50.500000          276.000000  ...
# 75%                 52.250000          345.500000  ...
# max                 57.000000          446.000000  ...
#
#        Total Service Points Won %  1st Serve Return Points Won %  \
# count                  100.000000                     100.000000
# mean                    62.640000                      29.580000
# std                      3.619588                       2.871595
# min                     49.000000                      21.000000
# 25%                     61.000000                      28.000000
# 50%                     62.000000                      30.000000
# 75%                     65.000000                      31.000000
# max                     71.000000                      37.000000
#
#        2nd Serve Return Points Won %  Break Points Opportunities  \
# count                      100.00000                  100.000000
# mean                        49.71000                  299.310000
# std                          3.13757                  145.812713
# min                         40.00000                   13.000000
# 25%                         48.00000                  198.000000
# 50%                         50.00000                  290.000000
# 75%                         52.00000                  383.000000
# max                         58.00000                  706.000000
#
#        Break Points Converted %  Return Games Played  Return Games Won %  \
# count                100.000000           100.000000          100.000000
# mean                  40.450000           518.170000           23.000000
# std                    5.166667           210.409896            5.430925
# min                    8.000000            39.000000            2.000000
# 25%                   38.750000           368.750000           20.000000
# 50%                   41.000000           546.000000           23.000000
# 75%                   43.250000           643.000000           26.000000
# max                   49.000000           988.000000           39.000000
#
#        Return Points Won %  Total Points Won %  Career Length
# count            100.00000          100.000000     100.000000
# mean              37.48000           50.050000       8.660000
# std                2.84793            1.996841       3.045845
# min               28.00000           42.000000       1.000000
# 25%               36.00000           49.000000       7.000000
# 50%               38.00000           50.000000       9.000000
# 75%               39.00000           51.000000      11.000000
# max               45.00000           56.000000      15.000000
#
# [8 rows x 23 columns]

# %%
categorical_data_all= df_players_2011.select_dtypes('object')
numerical_data_all= df_players_2011.select_dtypes('number')

# %%
#Distribution of all numeric categories

for i in numerical_data_all.columns:
    sns.histplot(numerical_data_all[i])
    plt.title(i,fontsize=13, fontweight= "bold")
    plt.show()

# %%
#Distribution of all numeric categories, evaluating outliers

for i in numerical_data_all.columns:
    sns.boxplot(numerical_data_all[i])
    plt.title(i,fontsize=13, fontweight= "bold")
    plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We'll plot the correlations using a Heat Map. 

plt.figure(figsize = (12, 9))
s = sns.heatmap(df_players_2011.corr(),
               cmap = 'RdBu',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# We see a high correlation between age and Career Length

# %% [markdown]
# ## Data frame with variables considered most insightful after Exploratory Data analysis

# %%
df_players_2011.columns
# Out:
# Index(['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Aces',
#        'Double Faults', '1st Serve %', '1st Serve Points Won %',
#        '2nd Serve Points Won %', 'Break Points Faced', 'Break Points Saved %',
#        'Service Games Played', 'Service Games Won %',
#        'Total Service Points Won %', '1st Serve Return Points Won %',
#        '2nd Serve Return Points Won %', 'Break Points Opportunities',
#        'Break Points Converted %', 'Return Games Played', 'Return Games Won %',
#        'Return Points Won %', 'Total Points Won %', 'Career Length'],
#       dtype='object')

# %%
eda_players_2011= df_players_2011.copy()
df_players_2011= df_players_2011.drop(['Age','1st Serve %', '1st Serve Points Won %',
                                   '2nd Serve Points Won %' , 'Break Points Faced', 'Break Points Saved %',
                                   'Service Games Won %', '1st Serve Return Points Won %', '2nd Serve Return Points Won %'
                                    ], axis=1)

# %%
df_players_2011.head()
# Out:
#    Ranking          Player  Points  Tourn Played  Aces  Double Faults  \
# 0        1  Novak Djokovic   13630            19   343            143
# 1        2    Rafael Nadal    9595            20   267            121
# 2        3   Roger Federer    8170            19   504             98
# 3        4     Andy Murray    7380            19   494            149
# 4        5    David Ferrer    4925            23   265            200
#
#    Service Games Played  Total Service Points Won %  \
# 0                   899                          68
# 1                   944                          67
# 2                   904                          71
# 3                   813                          65
# 4                   894                          66
#
#    Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 0                         692                        48                  860
# 1                         706                        46                  951
# 2                         593                        41                  877
# 3                         637                        46                  809
# 4                         627                        46                  877
#
#    Return Games Won %  Return Points Won %  Total Points Won %  Career Length
# 0                  39                   45                  56              8
# 1                  34                   43                  54             10
# 2                  28                   40                  55             13
# 3                  36                   44                  54              6
# 4                  33                   42                  54             11

# %%
df_players_2011.shape
# Out:
# (100, 15)

# %%
categorical_data= df_players_2011.select_dtypes('object')
numerical_data= df_players_2011.select_dtypes('number')

# %% [markdown]
# ## Visualize Raw Data

# %%
# We'll plot the data. We create a 12 by 9 inches figure.
# We have 2000 data points, which we'll scatter acrros Age and Income, located on positions 2 and 4 in our data set. 
plt.figure(figsize = (12, 9))
plt.scatter(df_players_2011.iloc[:, 4], df_players_2011.iloc[:, 0])
plt.xlabel('Aces')
plt.ylabel('Ranking')
plt.title('Visualization of raw data')
# Out:
# Text(0.5, 1.0, 'Visualization of raw data')

# %% [markdown]
# ## Standardization

# %%
scaler = StandardScaler()
players_2011_std = scaler.fit_transform(numerical_data)

# %% [markdown]
# ## ${\textbf{Hierarchical Clustering}}$

# %%
# Perform Hierarchical Clustering. The results are returned as a linkage matrix. 
hier_clust = linkage(players_2011_std, method = 'ward')

# %%
# We plot the results from the Hierarchical Clustering using a Dendrogram. 
# We truncate the dendrogram for better readability. The level p shows only the last p merged clusters
# We also omit showing the labels for each point.
plt.figure(figsize = (12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5, 
           show_leaf_counts = False, 
           no_labels = True)
plt.show()

# %% [markdown]
# ## ${\textbf{K-means Clustering}}$

# %%
# Perform K-means clustering. We consider 1 to 10 clusters, so our for loop runs 10 iterations.
# In addition we run the algortihm at many different starting points - k means plus plus. 
# And we set a random state for reproducibility.
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 1)
    kmeans.fit(players_2011_std)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot we choose the number of clusters. 
# We look for a kink in the graphic, after which the descent of wcss isn't as pronounced.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %%
# We run K-means with a fixed number of clusters. In our case 4.
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 1)

# %%
# We divide our data into the four clusters.
kmeans.fit(players_2011_std)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ## Results

# %%
# We create a new data frame with the original features and add a new column with the assigned clusters for each point.
df_players_2011_kmeans = df_players_2011.copy()
df_players_2011_kmeans['Segment K-means'] = kmeans.labels_

# %%
# Calculate mean values for the clusters
df_players_2011_analysis = df_players_2011_kmeans.groupby(['Segment K-means']).mean()
df_players_2011_analysis
# Out:
#                    Ranking       Points  Tourn Played        Aces  \
# Segment K-means
# 0                16.571429  2118.095238     25.047619  497.333333
# 1                81.718750   652.593750     27.093750  106.593750
# 2                 3.000000  8740.000000     20.000000  374.600000
# 3                49.333333   946.119048     25.952381  213.666667
#
#                  Double Faults  Service Games Played  \
# Segment K-means
# 0                   153.523810            748.142857
# 1                    73.531250            286.781250
# 2                   142.200000            890.800000
# 3                   127.142857            537.642857
#
#                  Total Service Points Won %  Break Points Opportunities  \
# Segment K-means
# 0                                 66.095238                  419.761905
# 1                                 60.031250                  154.281250
# 2                                 67.400000                  651.000000
# 3                                 62.333333                  307.714286
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# 0                               41.476190           743.380952
# 1                               38.593750           287.968750
# 2                               45.400000           874.800000
# 3                               40.761905           538.500000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# 0                         23.571429            37.714286           51.714286
# 1                         20.593750            36.343750           48.343750
# 2                         34.000000            42.800000           54.600000
# 3                         23.238095            37.595238           49.976190
#
#                  Career Length
# Segment K-means
# 0                     7.904762
# 1                     7.718750
# 2                     9.600000
# 3                     9.642857

# %%
# Compute the size and proportions of the two clusters
df_players_2011_analysis['N Obs'] = df_players_2011_kmeans[['Segment K-means','Ranking']].groupby(['Segment K-means']).count()
df_players_2011_analysis['Prop Obs'] = df_players_2011_analysis['N Obs'] / df_players_2011_analysis['N Obs'].sum()

# %%
df_players_2011_analysis
# Out:
#                    Ranking       Points  Tourn Played        Aces  \
# Segment K-means
# 0                16.571429  2118.095238     25.047619  497.333333
# 1                81.718750   652.593750     27.093750  106.593750
# 2                 3.000000  8740.000000     20.000000  374.600000
# 3                49.333333   946.119048     25.952381  213.666667
#
#                  Double Faults  Service Games Played  \
# Segment K-means
# 0                   153.523810            748.142857
# 1                    73.531250            286.781250
# 2                   142.200000            890.800000
# 3                   127.142857            537.642857
#
#                  Total Service Points Won %  Break Points Opportunities  \
# Segment K-means
# 0                                 66.095238                  419.761905
# 1                                 60.031250                  154.281250
# 2                                 67.400000                  651.000000
# 3                                 62.333333                  307.714286
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# 0                               41.476190           743.380952
# 1                               38.593750           287.968750
# 2                               45.400000           874.800000
# 3                               40.761905           538.500000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# 0                         23.571429            37.714286           51.714286
# 1                         20.593750            36.343750           48.343750
# 2                         34.000000            42.800000           54.600000
# 3                         23.238095            37.595238           49.976190
#
#                  Career Length  N Obs  Prop Obs
# Segment K-means
# 0                     7.904762     21      0.21
# 1                     7.718750     32      0.32
# 2                     9.600000      5      0.05
# 3                     9.642857     42      0.42

# %%
df_players_2011_analysis.rename({0:'Great-Players',
                                 1:'Worst-Players',
                                 2:'Top-Players',
                                 3:'Average-Players'
                                 })
# Out:
#                    Ranking       Points  Tourn Played        Aces  \
# Segment K-means
# Great-Players    16.571429  2118.095238     25.047619  497.333333
# Worst-Players    81.718750   652.593750     27.093750  106.593750
# Top-Players       3.000000  8740.000000     20.000000  374.600000
# Average-Players  49.333333   946.119048     25.952381  213.666667
#
#                  Double Faults  Service Games Played  \
# Segment K-means
# Great-Players       153.523810            748.142857
# Worst-Players        73.531250            286.781250
# Top-Players         142.200000            890.800000
# Average-Players     127.142857            537.642857
#
#                  Total Service Points Won %  Break Points Opportunities  \
# Segment K-means
# Great-Players                     66.095238                  419.761905
# Worst-Players                     60.031250                  154.281250
# Top-Players                       67.400000                  651.000000
# Average-Players                   62.333333                  307.714286
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# Great-Players                   41.476190           743.380952
# Worst-Players                   38.593750           287.968750
# Top-Players                     45.400000           874.800000
# Average-Players                 40.761905           538.500000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# Great-Players             23.571429            37.714286           51.714286
# Worst-Players             20.593750            36.343750           48.343750
# Top-Players               34.000000            42.800000           54.600000
# Average-Players           23.238095            37.595238           49.976190
#
#                  Career Length  N Obs  Prop Obs
# Segment K-means
# Great-Players         7.904762     21      0.21
# Worst-Players         7.718750     32      0.32
# Top-Players           9.600000      5      0.05
# Average-Players       9.642857     42      0.42

# %%
# Add the segment labels to our table
df_players_2011_kmeans['Labels'] = df_players_2011_kmeans['Segment K-means'].map({0:'Great-Players',
                                                                                 1:'Worst-Players',
                                                                                 2:'Top-Players',
                                                                                 3:'Average-Players'
                                                                                 })

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by  "Aces"

# %%
# We plot the results from the K-means algorithm. 
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2011_kmeans['Aces']
y_axis = df_players_2011_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_kmeans['Labels'], palette = ['g', 'r', 'y', 'm'])
plt.title('ATP Top 100 players 2011 K-means')
plt.show() 

#according to correlation map, these are the variables that have the highest impact on ranking 
#'Service Games Played'
#'Return Games Played'
#'Total Points Won %'
##SO, overall, experience is most valuable, it might explain the next gen tournement founded at 2017
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by "Break Points Opportunities"

# %%
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2011_kmeans['Break Points Opportunities']
y_axis = df_players_2011_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_kmeans['Labels'], palette = ['g', 'r', 'y', 'm'])
plt.title('ATP Top 100 players 2011 K-means')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by "Return Games Won"

# %%
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2011_kmeans['Return Games Won %']
y_axis = df_players_2011_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_kmeans['Labels'], palette = ['g', 'r', 'y', 'm'])
plt.title('ATP Top 100 players 2011 K-means')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## PCA Analysis

# %%
# Employ PCA to find a subset of components, which explain the variance in the data.
pca = PCA()

# %%
# Fit PCA with our standardized data.
pca.fit(players_2011_std)
# Out:
# PCA()

# %%
# The attribute shows how much variance is explained by each of the seven individual components.
pca.explained_variance_ratio_
# Out:
# array([5.08665264e-01, 1.82178526e-01, 1.00749529e-01, 7.13733321e-02,
#        4.70192862e-02, 2.68917919e-02, 2.28049872e-02, 1.83163294e-02,
#        1.03617361e-02, 8.71872764e-03, 1.32265210e-03, 1.08732548e-03,
#        4.76381553e-04, 3.41309710e-05])

# %%
# Plot the cumulative variance explained by total number of components.
# On this graph we choose the subset of components we want to keep. 
# Generally, we want to keep around 80 % of the explained variance.
plt.figure(figsize = (12,9))
plt.plot(range(1,15), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
# We choose three components. 5 seems the right choice according to the previous graph, due to it allows to preserve 
#around 85% of the data with only 1/5 of the variables.
pca = PCA(n_components = 4)

# %%
#Fit the model the our data with the selected number of components. In our case three.
pca.fit(players_2011_std)
# Out:
# PCA(n_components=4)

# %% [markdown]
# ### ${\textbf{PCA Results}}$

# %%
# Here we discucss the results from the PCA.
# The components attribute shows the loadings of each component on each of the seven original features.
# The loadings are the correlations between the components and the original features. 
pca.components_
# Out:
# array([[-0.33504657,  0.27332767, -0.15808461,  0.24381586,  0.23857569,
#          0.35141099,  0.25097399,  0.353051  ,  0.17643729,  0.34966638,
#          0.22060052,  0.20244051,  0.34162539,  0.02839913],
#        [-0.08670372, -0.06145866, -0.08582054,  0.403732  ,  0.05841671,
#          0.09808299,  0.38876704, -0.07674556, -0.37481837,  0.09600491,
#         -0.49300479, -0.50464087,  0.00342549, -0.02906026],
#        [ 0.00395749, -0.25870136,  0.66485121,  0.09386094,  0.46542027,
#          0.20329828, -0.22383797,  0.13094815, -0.01264915,  0.21446788,
#         -0.03318311, -0.0106275 , -0.21804635, -0.24921703],
#        [ 0.05801582,  0.12149675, -0.10630325,  0.12449246, -0.15521613,
#         -0.07329873,  0.04979334, -0.05975423,  0.06404053, -0.07708755,
#          0.04627835,  0.05583097,  0.0921544 , -0.94644828]])

# %%
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = numerical_data.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3', 'Component 4'])
df_pca_comp
# Out:
#               Ranking    Points  Tourn Played      Aces  Double Faults  \
# Component 1 -0.335047  0.273328     -0.158085  0.243816       0.238576
# Component 2 -0.086704 -0.061459     -0.085821  0.403732       0.058417
# Component 3  0.003957 -0.258701      0.664851  0.093861       0.465420
# Component 4  0.058016  0.121497     -0.106303  0.124492      -0.155216
#
#              Service Games Played  Total Service Points Won %  \
# Component 1              0.351411                    0.250974
# Component 2              0.098083                    0.388767
# Component 3              0.203298                   -0.223838
# Component 4             -0.073299                    0.049793
#
#              Break Points Opportunities  Break Points Converted %  \
# Component 1                    0.353051                  0.176437
# Component 2                   -0.076746                 -0.374818
# Component 3                    0.130948                 -0.012649
# Component 4                   -0.059754                  0.064041
#
#              Return Games Played  Return Games Won %  Return Points Won %  \
# Component 1             0.349666            0.220601             0.202441
# Component 2             0.096005           -0.493005            -0.504641
# Component 3             0.214468           -0.033183            -0.010627
# Component 4            -0.077088            0.046278             0.055831
#
#              Total Points Won %  Career Length
# Component 1            0.341625       0.028399
# Component 2            0.003425      -0.029060
# Component 3           -0.218046      -0.249217
# Component 4            0.092154      -0.946448

# %%
# Heat Map for Principal Components against original features. Again we use the RdBu color scheme and set borders to -1 and 1.
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu')
plt.yticks([0, 1, 2, 3], 
           ['Component 1', 'Component 2', 'Component 3', 'Component 4'],
           rotation = 45,
           fontsize = 9)
# Out:
# ([<matplotlib.axis.YTick at 0x23d759d03c8>,
#   <matplotlib.axis.YTick at 0x23d75429148>,
#   <matplotlib.axis.YTick at 0x23d75a3c3c8>,
#   <matplotlib.axis.YTick at 0x23d75a56708>],
#  [Text(0, 0, 'Component 1'),
#   Text(0, 1, 'Component 2'),
#   Text(0, 2, 'Component 3'),
#   Text(0, 3, 'Component 4')])

# %% [markdown]
# ### We can define the 4 components according their correlations with each component of the game as follows:
# #### Component 1: Players with the most complete game, they have high effectivity both serving and returning and have the highest amount of points accumulated.
# #### Component 2: Best servers but not good returners.
# #### Component 3: They play lots of tournements and make many mistakes with their service.
# #### Component 4: Inexperienced players/short careers.

# %%
##we had the loadings (correlation of between each original variable and a component) mapped before, but we'll now reduce
##the dimensionality to 5 components to make it more manageable

pca.transform(players_2011_std)
# Out:
# array([[ 7.89923651, -2.45712549, -2.73525338,  1.39204199],
#        [ 6.5026968 , -1.66368536, -1.92336086,  0.22973867],
#        [ 5.91477408,  0.7497951 , -2.78979097, -0.51637104],
#        [ 5.9960855 , -1.67404459, -1.33721807,  1.57135341],
#        [ 5.46420096, -1.37269535, -0.14017331, -0.68842587],
#        [ 4.75592037,  2.54279792,  1.20679438,  0.51595198],
#        [ 4.24091123,  0.05747546, -0.14067215,  0.10764207],
#        [ 3.51347746,  0.82448633, -0.54177133, -0.54018031],
#        [ 4.00574232,  0.07293397,  1.11046294, -0.24627345],
#        [ 3.17913603,  1.66098817,  1.5147694 , -0.14367504],
#        [ 3.1973165 ,  0.54141854, -0.71563616,  1.20528295],
#        [ 2.92049926, -1.06366901,  1.38742598, -0.41483911],
#        [ 2.52894196, -0.26720132, -1.33962278,  0.02211426],
#        [ 1.90697696,  2.01275355, -1.95772662, -0.21128943],
#        [ 2.80866113,  0.65642931,  2.66818711,  0.7139576 ],
#        [ 2.78288925,  0.49344215,  0.40138321,  0.43488463],
#        [ 2.03228082,  0.29055362, -0.24600206, -0.14542224],
#        [ 1.7442916 ,  4.99040668,  0.81896778,  1.37775239],
#        [ 1.86873292, -0.0712793 , -1.2499036 ,  0.16497701],
#        [ 1.89602955,  3.84057386,  1.55955264, -2.16864492],
#        [ 2.56529036,  0.72778977,  0.63947738,  0.78043796],
#        [ 2.29211563, -0.38623025,  1.07503974,  1.10152006],
#        [ 2.35688736, -1.06832408,  0.72601793, -0.58683436],
#        [ 2.31831111,  0.35410911,  1.09617519, -0.83259617],
#        [ 1.07119451, -0.4078552 ,  0.91854391,  1.11290408],
#        [ 1.21583792, -1.71045777,  0.01565042, -0.16644562],
#        [ 0.45127017, -0.58489351, -0.19629664,  0.15808653],
#        [ 1.08962375, -0.18316638,  0.1435315 , -2.25791921],
#        [ 1.58894458, -2.63499987,  0.39482032, -1.49611652],
#        [ 0.70723849,  1.46682895, -1.62237248, -0.98908432],
#        [ 0.84411119,  3.4390076 , -0.18897749,  2.0185363 ],
#        [ 2.41318289,  2.37245484,  1.62313853,  1.419563  ],
#        [ 0.48713097, -0.63556429, -0.87179435, -0.92889121],
#        [ 0.24777257, -0.46525807,  1.19867357, -0.53050925],
#        [ 0.82035285, -0.07388722,  0.26648551, -1.33100808],
#        [ 0.05008547,  1.03794074,  0.90317552,  0.27042245],
#        [ 0.66836551,  0.30726615,  0.67607264,  0.66778234],
#        [ 0.33870214, -0.15466494,  0.7208297 , -0.30620378],
#        [-0.32876645, -1.07145534, -0.34210316,  0.55168777],
#        [-0.83631647,  0.83602554, -0.07808729, -0.90447561],
#        [ 0.98843279, -1.92556955,  0.617723  , -1.30704895],
#        [-1.27872852,  1.47537983, -1.29389086,  1.95922082],
#        [ 0.52323669,  1.07656671,  0.77232952, -0.72013904],
#        [ 1.02231952,  0.64248631,  1.05120536,  0.01041558],
#        [ 1.28784487, -0.45464795,  0.55983439,  0.85010671],
#        [-0.07903352, -1.86545173,  1.73515905, -0.21111184],
#        [-0.84144871,  2.04417988, -0.954554  , -1.08398769],
#        [ 0.64220622, -2.07391433,  3.03440266, -0.17543694],
#        [ 0.7249286 , -0.57317851, -0.55248839, -1.10673699],
#        [-0.28908297, -0.86714867, -2.93826834, -0.83695633],
#        [-0.11241506, -0.71941261, -2.00676223, -0.95407437],
#        [-0.25266031,  0.44068385,  0.30838224, -0.90045432],
#        [ 0.65995657, -0.66584811,  0.64986881, -1.37576142],
#        [-1.74691065,  3.40232841, -1.85992162, -0.09272333],
#        [ 0.37685366, -0.61809228,  0.1774775 ,  0.52963872],
#        [-1.32084638,  5.22220225, -1.09863738, -0.5975474 ],
#        [ 0.29761446, -0.89735092,  0.21712629, -0.22546562],
#        [-1.0633626 ,  0.30285623,  0.19473831, -0.6245825 ],
#        [-0.73047622,  0.27788898, -1.43418598, -0.88088546],
#        [-0.95944587, -1.26556393,  1.23885955, -0.70303173],
#        [-0.80408432,  1.95584466,  0.58716199,  0.2817922 ],
#        [-0.77538393,  0.54652673,  0.88118805, -0.03089623],
#        [-0.16378902,  1.00856437,  0.33352877, -0.54242781],
#        [-0.51225648, -0.76498131, -1.50623179, -0.51429525],
#        [ 0.22424302, -0.38848348,  2.42522833, -0.81244343],
#        [-1.80047632, -0.46288051,  0.71427396,  1.38128213],
#        [-2.23967069, -0.41199932, -1.27268888, -0.9826193 ],
#        [-4.10775879, -1.74851091,  0.12676157, -0.10396571],
#        [-1.95485752, -3.41156627,  0.5248133 , -1.75975405],
#        [-3.58649793,  0.91521714,  0.13069904,  0.3939689 ],
#        [-1.34041345, -0.88586669, -0.67604128, -0.95801709],
#        [-1.08197917, -1.31238579,  0.49871083,  1.39259277],
#        [-2.49756886,  0.33911826,  0.14842131,  0.48312168],
#        [-2.22637063, -1.18562574, -0.9542464 , -0.52842296],
#        [-3.56319797, -2.31281327,  0.02945981,  0.30664049],
#        [-0.89114379,  0.92683995,  1.36846487,  1.45753427],
#        [-0.78814376, -0.48969671,  0.30662429, -0.89253599],
#        [-3.56658808,  0.59904955, -1.78709413,  0.5889931 ],
#        [-1.38451795,  0.20762212,  0.30659388,  1.38856746],
#        [-1.94265525,  0.09801356, -1.30477384, -0.45932066],
#        [-2.90675265, -3.89872131, -1.14851782,  3.1089786 ],
#        [-2.63462562,  0.37463065,  0.25777216, -0.62583449],
#        [-2.66468359, -0.72961668, -1.25818861,  0.15743072],
#        [-1.24745963, -1.01580903,  0.14777973,  1.92315532],
#        [-3.128634  , -0.16534763, -1.50232042, -0.8585407 ],
#        [-2.64235423, -0.5534344 , -1.20600899,  1.58423642],
#        [-1.96210224, -0.25427722,  1.21554412,  0.22608262],
#        [-2.60344433, -1.2016522 , -1.664576  ,  0.70535548],
#        [-3.13018717, -0.23070169,  1.84628317,  0.12229918],
#        [-1.1463879 , -0.10192468, -0.59058306, -0.61782343],
#        [-2.53296558, -0.81264658,  0.39156612,  1.13002584],
#        [-1.46737053, -1.91805097,  0.09650429,  0.94193359],
#        [-2.25203619,  1.66823556, -0.70924709,  1.30563445],
#        [-3.63527981,  0.34606874, -0.84744542,  1.09117363],
#        [-3.79817379, -1.35690359,  1.30460493,  1.46062878],
#        [-1.85765507, -1.30935968,  1.90555596,  0.16148689],
#        [-6.87477997, -1.12107935,  0.09783051, -0.94459576],
#        [-7.87788514,  4.52702342, -0.28479244, -0.32876014],
#        [-2.1141172 , -0.81362005,  0.20151084, -1.43831501],
#        [-1.8891128 ,  1.05778646, -0.20093614, -1.15921633]])

# %%
scores_pca = pca.transform(players_2011_std)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA}}$

# %%
# We fit K means using the transformed data from the PCA.
wcss = []
##within clusters sum of squares (wcss)
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 1)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
# Plot the Within Cluster Sum of Squares for the K-means PCA model. Here we make a decission about the number of clusters.
# Again it looks like four is the best option.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
# We have chosen four clusters, so we run K-means with number of clusters equals four. 
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state =1)

# %%
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA Results}}$

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters.
df_players_2011_pca_kmeans = pd.concat([df_players_2011.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
df_players_2011_pca_kmeans.columns.values[-4: ] = ['Component 1', 'Component 2', 'Component 3', 'Component 4']
# The last column we add contains the pca k-means clustering labels.
df_players_2011_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

# %%
df_players_2011_pca_kmeans
# Out:
#     Ranking           Player  Points  Tourn Played  Aces  Double Faults  \
# 0         1   Novak Djokovic   13630            19   343            143
# 1         2     Rafael Nadal    9595            20   267            121
# 2         3    Roger Federer    8170            19   504             98
# 3         4      Andy Murray    7380            19   494            149
# 4         5     David Ferrer    4925            23   265            200
# ..      ...              ...     ...           ...   ...            ...
# 95       96     Tobias Kamke     582            33    87            134
# 96       97      Eric Prodon     581            29     7             17
# 97       98     Andreas Beck     580            30     8              4
# 98       99  Michael Russell     577            29    88            127
# 99      100   Michael Berrer     567            26   194            114
#
#     Service Games Played  Total Service Points Won %  \
# 0                    899                          68
# 1                    944                          67
# 2                    904                          71
# 3                    813                          65
# 4                    894                          66
# ..                   ...                         ...
# 95                   426                          59
# 96                    39                          49
# 97                    49                          60
# 98                   350                          61
# 99                   451                          63
#
#     Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 0                          692                        48                  860
# 1                          706                        46                  951
# 2                          593                        41                  877
# 3                          637                        46                  809
# 4                          627                        46                  877
# ..                         ...                       ...                  ...
# 95                         268                        40                  424
# 96                          22                        32                   39
# 97                          13                         8                   50
# 98                         171                        45                  353
# 99                         225                        36                  458
#
#     Return Games Won %  Return Points Won %  Total Points Won %  \
# 0                   39                   45                  56
# 1                   34                   43                  54
# 2                   28                   40                  55
# 3                   36                   44                  54
# 4                   33                   42                  54
# ..                 ...                  ...                 ...
# 95                  25                   38                  49
# 96                  18                   35                  42
# 97                   2                   28                  44
# 98                  22                   36                  49
# 99                  17                   35                  49
#
#     Career Length  Component 1  Component 2  Component 3  Component 4  \
# 0               8     7.899237    -2.457125    -2.735253     1.392042
# 1              10     6.502697    -1.663685    -1.923361     0.229739
# 2              13     5.914774     0.749795    -2.789791    -0.516371
# 3               6     5.996086    -1.674045    -1.337218     1.571353
# 4              11     5.464201    -1.372695    -0.140173    -0.688426
# ..            ...          ...          ...          ...          ...
# 95              7    -1.857655    -1.309360     1.905556     0.161487
# 96             11    -6.874780    -1.121079     0.097831    -0.944596
# 97              8    -7.877885     4.527023    -0.284792    -0.328760
# 98             13    -2.114117    -0.813620     0.201511    -1.438315
# 99             12    -1.889113     1.057786    -0.200936    -1.159216
#
#     Segment K-means PCA
# 0                     3
# 1                     3
# 2                     3
# 3                     3
# 4                     3
# ..                  ...
# 95                    1
# 96                    1
# 97                    1
# 98                    1
# 99                    1
#
# [100 rows x 20 columns]

# %%
# We calculate the means by segments.
df_players_2011_pca_kmeans_freq = df_players_2011_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_players_2011_pca_kmeans_freq
# Out:
#                        Ranking       Points  Tourn Played        Aces  \
# Segment K-means PCA
# 0                    19.250000  1990.666667     25.125000  472.625000
# 1                    80.882353   659.117647     26.794118  128.617647
# 2                    49.270270   943.621622     26.189189  192.243243
# 3                     3.000000  8740.000000     20.000000  374.600000
#
#                      Double Faults  Service Games Played  \
# Segment K-means PCA
# 0                       152.875000            735.625000
# 1                        78.911765            300.558824
# 2                       123.378378            529.594595
# 3                       142.200000            890.800000
#
#                      Total Service Points Won %  Break Points Opportunities  \
# Segment K-means PCA
# 0                                     65.666667                  414.208333
# 1                                     60.529412                  156.617647
# 2                                     61.972973                  308.378378
# 3                                     67.400000                  651.000000
#
#                      Break Points Converted %  Return Games Played  \
# Segment K-means PCA
# 0                                   41.541667           731.125000
# 1                                   38.382353           301.411765
# 2                                   40.972973           531.027027
# 3                                   45.400000           874.800000
#
#                      Return Games Won %  Return Points Won %  \
# Segment K-means PCA
# 0                             23.666667            37.791667
# 1                             20.029412            36.000000
# 2                             23.810811            37.918919
# 3                             34.000000            42.800000
#
#                      Total Points Won %  Career Length  Component 1  \
# Segment K-means PCA
# 0                             51.541667       7.666667     2.481378
# 1                             48.441176       7.382353    -2.660427
# 2                             49.945946      10.351351    -0.023663
# 3                             54.600000       9.600000     6.355399
#
#                      Component 2  Component 3  Component 4
# Segment K-means PCA
# 0                       0.908371     0.499028     0.272762
# 1                      -0.048704    -0.223675     0.445602
# 2                      -0.371006     0.123083    -0.640138
# 3                      -1.283551    -1.785159     0.397667

# %%
# Calculate the size of each cluster and its proportion to the entire data set.
df_players_2011_pca_kmeans_freq['N Obs'] = df_players_2011_pca_kmeans[['Segment K-means PCA','Ranking']].groupby(['Segment K-means PCA']).count()
df_players_2011_pca_kmeans_freq['Prop Obs'] = df_players_2011_pca_kmeans_freq['N Obs'] / df_players_2011_pca_kmeans_freq['N Obs'].sum()
df_players_2011_pca_kmeans_freq = df_players_2011_pca_kmeans_freq.rename({0:'Great-Players', 
                                                          1:'Worst-Players',
                                                          2:'Average-Players',
                                                          3: 'Top-Players'})               
df_players_2011_pca_kmeans_freq
# Out:
#                        Ranking       Points  Tourn Played        Aces  \
# Segment K-means PCA
# Great-Players        19.250000  1990.666667     25.125000  472.625000
# Worst-Players        80.882353   659.117647     26.794118  128.617647
# Average-Players      49.270270   943.621622     26.189189  192.243243
# Top-Players           3.000000  8740.000000     20.000000  374.600000
#
#                      Double Faults  Service Games Played  \
# Segment K-means PCA
# Great-Players           152.875000            735.625000
# Worst-Players            78.911765            300.558824
# Average-Players         123.378378            529.594595
# Top-Players             142.200000            890.800000
#
#                      Total Service Points Won %  Break Points Opportunities  \
# Segment K-means PCA
# Great-Players                         65.666667                  414.208333
# Worst-Players                         60.529412                  156.617647
# Average-Players                       61.972973                  308.378378
# Top-Players                           67.400000                  651.000000
#
#                      Break Points Converted %  Return Games Played  \
# Segment K-means PCA
# Great-Players                       41.541667           731.125000
# Worst-Players                       38.382353           301.411765
# Average-Players                     40.972973           531.027027
# Top-Players                         45.400000           874.800000
#
#                      Return Games Won %  Return Points Won %  \
# Segment K-means PCA
# Great-Players                 23.666667            37.791667
# Worst-Players                 20.029412            36.000000
# Average-Players               23.810811            37.918919
# Top-Players                   34.000000            42.800000
#
#                      Total Points Won %  Career Length  Component 1  \
# Segment K-means PCA
# Great-Players                 51.541667       7.666667     2.481378
# Worst-Players                 48.441176       7.382353    -2.660427
# Average-Players               49.945946      10.351351    -0.023663
# Top-Players                   54.600000       9.600000     6.355399
#
#                      Component 2  Component 3  Component 4  N Obs  Prop Obs
# Segment K-means PCA
# Great-Players           0.908371     0.499028     0.272762     24      0.24
# Worst-Players          -0.048704    -0.223675     0.445602     34      0.34
# Average-Players        -0.371006     0.123083    -0.640138     37      0.37
# Top-Players            -1.283551    -1.785159     0.397667      5      0.05

# %%
df_players_2011_pca_kmeans['Legend'] = df_players_2011_pca_kmeans['Segment K-means PCA'].map({0:'Great-Players', 
                                                                                              1:'Worst-Players',
                                                                                              2:'Average-Players',
                                                                                              3: 'Top-Players'})

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
x_axis = df_players_2011_pca_kmeans['Component 1']
y_axis = df_players_2011_pca_kmeans['Component 2']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
x_axis = df_players_2011_pca_kmeans['Component 1']
y_axis = df_players_2011_pca_kmeans['Component 4']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
