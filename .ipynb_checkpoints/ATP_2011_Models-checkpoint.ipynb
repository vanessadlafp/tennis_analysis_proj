# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import scipy


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#For standardizing features

from sklearn.preprocessing import StandardScaler

#Hierarchical clustering with the Sci Py library. We'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# ## Load the data

# %%
df_players_2011= pd.read_csv("players_2011.csv")
df_players_2019= pd.read_csv("players_2019.csv")

# %% [markdown]
# ## Data exploration

# %% [markdown]
# ### Players' performance 2011

# %%
df_players_2011.head()
# Out:
#    Unnamed: 0  Ranking  Move  Country          Player  Age  Points  \
# 0           0        1   NaN      NaN  Novak Djokovic   24   13630
# 1           1        2   NaN      NaN    Rafael Nadal   25    9595
# 2           2        3   NaN      NaN   Roger Federer   30    8170
# 3           3        4   NaN      NaN     Andy Murray   24    7380
# 4           4        5   NaN      NaN    David Ferrer   29    4925
#
#    Tourn Played  Points Dropping  Next Best  ...  Service Games Won  \
# 0            19                0          0  ...                86%
# 1            20                0          0  ...                83%
# 2            19                0          0  ...                90%
# 3            19                0          0  ...                80%
# 4            23                0          0  ...                83%
#
#    Total Service Points Won  1st Serve Return Points Won  \
# 0                       68%                          36%
# 1                       67%                          34%
# 2                       71%                          33%
# 3                       65%                          37%
# 4                       66%                          33%
#
#    2nd Serve Return Points Won Break Points Opportunities  \
# 0                          58%                        692
# 1                          57%                        706
# 2                          51%                        593
# 3                          56%                        637
# 4                          56%                        627
#
#   Break Points Converted Return Games Played  Return Games Won  \
# 0                    48%                 860               39%
# 1                    46%                 951               34%
# 2                    41%                 877               28%
# 3                    46%                 809               36%
# 4                    46%                 877               33%
#
#   Return Points Won  Total Points Won
# 0               45%               56%
# 1               43%               54%
# 2               40%               55%
# 3               44%               54%
# 4               42%               54%
#
# [5 rows x 30 columns]

# %%
df_players_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   100 non-null    int64
#  1   Ranking                      100 non-null    int64
#  2   Move                         0 non-null      float64
#  3   Country                      0 non-null      float64
#  4   Player                       100 non-null    object
#  5   Age                          100 non-null    int64
#  6   Points                       100 non-null    int64
#  7   Tourn Played                 100 non-null    int64
#  8   Points Dropping              100 non-null    int64
#  9   Next Best                    100 non-null    int64
#  10  Turned Pro                   100 non-null    int64
#  11  index                        100 non-null    int64
#  12  Aces                         100 non-null    int64
#  13  Double Faults                100 non-null    int64
#  14  1st Serve                    100 non-null    object
#  15  1st Serve Points Won         100 non-null    object
#  16  2nd Serve Points Won         100 non-null    object
#  17  Break Points Faced           100 non-null    int64
#  18  Break Points Saved           100 non-null    object
#  19  Service Games Played         100 non-null    int64
#  20  Service Games Won            100 non-null    object
#  21  Total Service Points Won     100 non-null    object
#  22  1st Serve Return Points Won  100 non-null    object
#  23  2nd Serve Return Points Won  100 non-null    object
#  24  Break Points Opportunities   100 non-null    int64
#  25  Break Points Converted       100 non-null    object
#  26  Return Games Played          100 non-null    int64
#  27  Return Games Won             100 non-null    object
#  28  Return Points Won            100 non-null    object
#  29  Total Points Won             100 non-null    object
# dtypes: float64(2), int64(15), object(13)
# memory usage: 23.6+ KB

# %% [markdown]
# We see some columns with  numeric values aren't considered as such due to they have the percentage symbols next to it
# and that columns Move and Country have NaN values

# %%
df_players_2011= df_players_2011.drop(['Unnamed: 0', 'Move', 'Country', 'Points Dropping', 'Next Best','index'], axis=1)
df_players_2011
# Out:
#     Ranking           Player  Age  Points  Tourn Played  Turned Pro  Aces  \
# 0         1   Novak Djokovic   24   13630            19        2003   343
# 1         2     Rafael Nadal   25    9595            20        2001   267
# 2         3    Roger Federer   30    8170            19        1998   504
# 3         4      Andy Murray   24    7380            19        2005   494
# 4         5     David Ferrer   29    4925            23        2000   265
# ..      ...              ...  ...     ...           ...         ...   ...
# 95       96     Tobias Kamke   25     582            33        2004    87
# 96       97      Eric Prodon   30     581            29        2000     7
# 97       98     Andreas Beck   25     580            30        2003     8
# 98       99  Michael Russell   33     577            29        1998    88
# 99      100   Michael Berrer   31     567            26        1999   194
#
#     Double Faults 1st Serve 1st Serve Points Won  ... Service Games Won  \
# 0             143       65%                  74%  ...               86%
# 1             121       68%                  71%  ...               83%
# 2              98       64%                  79%  ...               90%
# 3             149       59%                  75%  ...               80%
# 4             200       61%                  72%  ...               83%
# ..            ...       ...                  ...  ...               ...
# 95            134       57%                  66%  ...               72%
# 96             17       54%                  57%  ...               51%
# 97              4       65%                  63%  ...               76%
# 98            127       64%                  69%  ...               73%
# 99            114       64%                  71%  ...               78%
#
#     Total Service Points Won 1st Serve Return Points Won  \
# 0                        68%                         36%
# 1                        67%                         34%
# 2                        71%                         33%
# 3                        65%                         37%
# 4                        66%                         33%
# ..                       ...                         ...
# 95                       59%                         31%
# 96                       49%                         26%
# 97                       60%                         22%
# 98                       61%                         28%
# 99                       63%                         29%
#
#     2nd Serve Return Points Won Break Points Opportunities  \
# 0                           58%                        692
# 1                           57%                        706
# 2                           51%                        593
# 3                           56%                        637
# 4                           56%                        627
# ..                          ...                        ...
# 95                          51%                        268
# 96                          52%                         22
# 97                          41%                         13
# 98                          48%                        171
# 99                          47%                        225
#
#    Break Points Converted Return Games Played Return Games Won  \
# 0                     48%                 860              39%
# 1                     46%                 951              34%
# 2                     41%                 877              28%
# 3                     46%                 809              36%
# 4                     46%                 877              33%
# ..                    ...                 ...              ...
# 95                    40%                 424              25%
# 96                    32%                  39              18%
# 97                     8%                  50               2%
# 98                    45%                 353              22%
# 99                    36%                 458              17%
#
#     Return Points Won Total Points Won
# 0                 45%              56%
# 1                 43%              54%
# 2                 40%              55%
# 3                 44%              54%
# 4                 42%              54%
# ..                ...              ...
# 95                38%              49%
# 96                35%              42%
# 97                28%              44%
# 98                36%              49%
# 99                35%              49%
#
# [100 rows x 24 columns]

# %%
df_players_2011['1st Serve']= df_players_2011['1st Serve'].apply(lambda x: int(x.strip('%')))
df_players_2011['1st Serve Points Won']= df_players_2011['1st Serve Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['2nd Serve Points Won']= df_players_2011['2nd Serve Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Break Points Saved']= df_players_2011['Break Points Saved'].apply(lambda x: int(x.strip('%')))
df_players_2011['Service Games Won']= df_players_2011['Service Games Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Total Service Points Won']= df_players_2011['Total Service Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['1st Serve Return Points Won']= df_players_2011['1st Serve Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['2nd Serve Return Points Won']= df_players_2011['2nd Serve Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Break Points Converted']= df_players_2011['Break Points Converted'].apply(lambda x: int(x.strip('%')))
df_players_2011['Return Games Won']= df_players_2011['Return Games Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Return Points Won']= df_players_2011['Return Points Won'].apply(lambda x: int(x.strip('%')))
df_players_2011['Total Points Won']= df_players_2011['Total Points Won'].apply(lambda x: int(x.strip('%')))

df_players_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ranking                      100 non-null    int64
#  1   Player                       100 non-null    object
#  2   Age                          100 non-null    int64
#  3   Points                       100 non-null    int64
#  4   Tourn Played                 100 non-null    int64
#  5   Turned Pro                   100 non-null    int64
#  6   Aces                         100 non-null    int64
#  7   Double Faults                100 non-null    int64
#  8   1st Serve                    100 non-null    int64
#  9   1st Serve Points Won         100 non-null    int64
#  10  2nd Serve Points Won         100 non-null    int64
#  11  Break Points Faced           100 non-null    int64
#  12  Break Points Saved           100 non-null    int64
#  13  Service Games Played         100 non-null    int64
#  14  Service Games Won            100 non-null    int64
#  15  Total Service Points Won     100 non-null    int64
#  16  1st Serve Return Points Won  100 non-null    int64
#  17  2nd Serve Return Points Won  100 non-null    int64
#  18  Break Points Opportunities   100 non-null    int64
#  19  Break Points Converted       100 non-null    int64
#  20  Return Games Played          100 non-null    int64
#  21  Return Games Won             100 non-null    int64
#  22  Return Points Won            100 non-null    int64
#  23  Total Points Won             100 non-null    int64
# dtypes: int64(23), object(1)
# memory usage: 18.9+ KB

# %%
df_players_2011.columns
# Out:
# Index(['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Turned Pro',
#        'Aces', 'Double Faults', '1st Serve', '1st Serve Points Won',
#        '2nd Serve Points Won', 'Break Points Faced', 'Break Points Saved',
#        'Service Games Played', 'Service Games Won', 'Total Service Points Won',
#        '1st Serve Return Points Won', '2nd Serve Return Points Won',
#        'Break Points Opportunities', 'Break Points Converted',
#        'Return Games Played', 'Return Games Won', 'Return Points Won',
#        'Total Points Won'],
#       dtype='object')

# %%
cols= ['Ranking', 'Player', 'Age', 'Points', 'Tourn Played', 'Turned Pro',
       'Aces', 'Double Faults', '1st Serve %', '1st Serve Points Won %',
       '2nd Serve Points Won %', 'Break Points Faced', 'Break Points Saved %',
       'Service Games Played', 'Service Games Won %', 'Total Service Points Won %',
       '1st Serve Return Points Won %', '2nd Serve Return Points Won %',
       'Break Points Opportunities', 'Break Points Converted %',
       'Return Games Played', 'Return Games Won %', 'Return Points Won %',
       'Total Points Won %']


df_players_2011.columns= cols

# %%
df_players_2011
# Out:
#     Ranking           Player  Age  Points  Tourn Played  Turned Pro  Aces  \
# 0         1   Novak Djokovic   24   13630            19        2003   343
# 1         2     Rafael Nadal   25    9595            20        2001   267
# 2         3    Roger Federer   30    8170            19        1998   504
# 3         4      Andy Murray   24    7380            19        2005   494
# 4         5     David Ferrer   29    4925            23        2000   265
# ..      ...              ...  ...     ...           ...         ...   ...
# 95       96     Tobias Kamke   25     582            33        2004    87
# 96       97      Eric Prodon   30     581            29        2000     7
# 97       98     Andreas Beck   25     580            30        2003     8
# 98       99  Michael Russell   33     577            29        1998    88
# 99      100   Michael Berrer   31     567            26        1999   194
#
#     Double Faults  1st Serve %  1st Serve Points Won %  ...  \
# 0             143           65                      74  ...
# 1             121           68                      71  ...
# 2              98           64                      79  ...
# 3             149           59                      75  ...
# 4             200           61                      72  ...
# ..            ...          ...                     ...  ...
# 95            134           57                      66  ...
# 96             17           54                      57  ...
# 97              4           65                      63  ...
# 98            127           64                      69  ...
# 99            114           64                      71  ...
#
#     Service Games Won %  Total Service Points Won %  \
# 0                    86                          68
# 1                    83                          67
# 2                    90                          71
# 3                    80                          65
# 4                    83                          66
# ..                  ...                         ...
# 95                   72                          59
# 96                   51                          49
# 97                   76                          60
# 98                   73                          61
# 99                   78                          63
#
#     1st Serve Return Points Won %  2nd Serve Return Points Won %  \
# 0                              36                             58
# 1                              34                             57
# 2                              33                             51
# 3                              37                             56
# 4                              33                             56
# ..                            ...                            ...
# 95                             31                             51
# 96                             26                             52
# 97                             22                             41
# 98                             28                             48
# 99                             29                             47
#
#     Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 0                          692                        48                  860
# 1                          706                        46                  951
# 2                          593                        41                  877
# 3                          637                        46                  809
# 4                          627                        46                  877
# ..                         ...                       ...                  ...
# 95                         268                        40                  424
# 96                          22                        32                   39
# 97                          13                         8                   50
# 98                         171                        45                  353
# 99                         225                        36                  458
#
#     Return Games Won %  Return Points Won %  Total Points Won %
# 0                   39                   45                  56
# 1                   34                   43                  54
# 2                   28                   40                  55
# 3                   36                   44                  54
# 4                   33                   42                  54
# ..                 ...                  ...                 ...
# 95                  25                   38                  49
# 96                  18                   35                  42
# 97                   2                   28                  44
# 98                  22                   36                  49
# 99                  17                   35                  49
#
# [100 rows x 24 columns]

# %%
df_players_2011['Career Length']= 2011- df_players_2011['Turned Pro']
df_players_2011= df_players_2011.drop(['Turned Pro'], axis=1)
df_players_2011['Career Length']
# Out:
# 0      8
# 1     10
# 2     13
# 3      6
# 4     11
#       ..
# 95     7
# 96    11
# 97     8
# 98    13
# 99    12
# Name: Career Length, Length: 100, dtype: int64

# %%
df_players_2011.describe()
# Out:
#           Ranking         Age        Points  Tourn Played        Aces  \
# count  100.000000  100.000000    100.000000      100.0000  100.000000
# mean    50.500000   26.670000   1488.000000       25.8300  247.020000
# std     29.011492    3.250656   1908.893561        3.3335  187.221037
# min      1.000000   19.000000    567.000000       18.0000    7.000000
# 25%     25.750000   24.000000    668.250000       24.0000  109.000000
# 50%     50.500000   26.500000    907.500000       26.0000  183.000000
# 75%     75.250000   29.250000   1358.750000       28.0000  347.750000
# max    100.000000   33.000000  13630.000000       35.0000  825.000000
#
#        Double Faults  1st Serve %  1st Serve Points Won %  \
# count     100.000000   100.000000              100.000000
# mean      116.280000    61.050000               70.330000
# std        49.167017     4.085884                4.649438
# min         4.000000    51.000000               57.000000
# 25%        78.000000    58.000000               67.000000
# 50%       119.000000    61.000000               70.000000
# 75%       148.250000    64.000000               74.000000
# max       231.000000    71.000000               80.000000
#
#        2nd Serve Points Won %  Break Points Faced  ...  \
# count              100.000000          100.000000  ...
# mean                50.670000          276.850000  ...
# std                  3.055232           96.353031  ...
# min                 39.000000           27.000000  ...
# 25%                 49.000000          224.000000  ...
# 50%                 50.500000          276.000000  ...
# 75%                 52.250000          345.500000  ...
# max                 57.000000          446.000000  ...
#
#        Total Service Points Won %  1st Serve Return Points Won %  \
# count                  100.000000                     100.000000
# mean                    62.640000                      29.580000
# std                      3.619588                       2.871595
# min                     49.000000                      21.000000
# 25%                     61.000000                      28.000000
# 50%                     62.000000                      30.000000
# 75%                     65.000000                      31.000000
# max                     71.000000                      37.000000
#
#        2nd Serve Return Points Won %  Break Points Opportunities  \
# count                      100.00000                  100.000000
# mean                        49.71000                  299.310000
# std                          3.13757                  145.812713
# min                         40.00000                   13.000000
# 25%                         48.00000                  198.000000
# 50%                         50.00000                  290.000000
# 75%                         52.00000                  383.000000
# max                         58.00000                  706.000000
#
#        Break Points Converted %  Return Games Played  Return Games Won %  \
# count                100.000000           100.000000          100.000000
# mean                  40.450000           518.170000           23.000000
# std                    5.166667           210.409896            5.430925
# min                    8.000000            39.000000            2.000000
# 25%                   38.750000           368.750000           20.000000
# 50%                   41.000000           546.000000           23.000000
# 75%                   43.250000           643.000000           26.000000
# max                   49.000000           988.000000           39.000000
#
#        Return Points Won %  Total Points Won %  Career Length
# count            100.00000          100.000000     100.000000
# mean              37.48000           50.050000       8.660000
# std                2.84793            1.996841       3.045845
# min               28.00000           42.000000       1.000000
# 25%               36.00000           49.000000       7.000000
# 50%               38.00000           50.000000       9.000000
# 75%               39.00000           51.000000      11.000000
# max               45.00000           56.000000      15.000000
#
# [8 rows x 23 columns]

# %%
df_players_2011.sort_values(by='Career Length',ascending=False)
# Out:
#     Ranking               Player  Age  Points  Tourn Played  Aces  \
# 27       28       Radek Stepanek   33    1275            27   193
# 19       20      Feliciano Lopez   30    1755            28   734
# 68       69     Filippo Volandri   30     696            31    13
# 28       29   Juan Ignacio Chela   32    1270            28    93
# 29       30        Ivan Ljubicic   32    1270            22   451
# ..      ...                  ...  ...     ...           ...   ...
# 75       76      Grigor Dimitrov   20     666            28   234
# 83       84     Somdev Devvarman   26     631            27   133
# 30       31         Milos Raonic   20    1255            24   637
# 41       42        Bernard Tomic   19     970            21   183
# 80       81  Cedrik-Marcel Stebe   21     652            24    23
#
#     Double Faults  1st Serve %  1st Serve Points Won %  \
# 27            149           61                      71
# 19            219           58                      78
# 68             93           67                      60
# 28            118           66                      65
# 29             78           57                      77
# ..            ...          ...                     ...
# 75            158           60                      71
# 83             56           62                      67
# 30            102           64                      79
# 41             66           66                      71
# 80             27           58                      63
#
#     2nd Serve Points Won %  ...  Total Service Points Won %  \
# 27                      52  ...                          63
# 19                      53  ...                          67
# 68                      46  ...                          55
# 28                      50  ...                          60
# 29                      52  ...                          66
# ..                     ...  ...                         ...
# 75                      51  ...                          63
# 83                      51  ...                          61
# 30                      53  ...                          70
# 41                      50  ...                          64
# 80                      44  ...                          55
#
#     1st Serve Return Points Won %  2nd Serve Return Points Won %  \
# 27                             30                             52
# 19                             26                             44
# 68                             33                             53
# 28                             34                             54
# 29                             27                             47
# ..                            ...                            ...
# 75                             30                             47
# 83                             30                             50
# 30                             26                             46
# 41                             26                             48
# 80                             36                             56
#
#     Break Points Opportunities  Break Points Converted %  Return Games Played  \
# 27                         383                        39                  611
# 19                         346                        34                  782
# 68                         222                        45                  318
# 28                         445                        46                  646
# 29                         260                        43                  548
# ..                         ...                       ...                  ...
# 75                         288                        35                  493
# 83                         287                        40                  462
# 30                         248                        39                  605
# 41                         205                        34                  392
# 80                          63                        48                   91
#
#     Return Games Won %  Return Points Won %  Total Points Won %  Career Length
# 27                  25                   38                  51             15
# 19                  15                   33                  50             14
# 68                  31                   41                  48             14
# 28                  32                   42                  51             13
# 29                  20                   35                  51             13
# ..                 ...                  ...                 ...            ...
# 75                  20                   36                  50              3
# 83                  25                   39                  50              3
# 30                  16                   33                  51              3
# 41                  18                   35                  50              3
# 80                  33                   42                  49              1
#
# [100 rows x 24 columns]

# %%
categorical_data= df_players_2011.select_dtypes('object')
numerical_data= df_players_2011.select_dtypes('number')

# %%
#Distribution of all numeric categories

for i in numerical_data.columns:
    sns.histplot(numerical_data[i])
    plt.title(i,fontsize=13, fontweight= "bold")
    plt.show()

# %%
#Distribution of all numeric categories, evaluating outliers

for i in numerical_data.columns:
    sns.boxplot(numerical_data[i])
    plt.title(i,fontsize=13, fontweight= "bold")
    plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We'll plot the correlations using a Heat Map. 

plt.figure(figsize = (12, 9))
s = sns.heatmap(df_players_2011.corr(),
               cmap = 'RdBu',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# We see a high correlation between age and Career Length

# %% [markdown]
# ## Visualize Raw Data

# %%
# We'll plot the data. We create a 12 by 9 inches figure.
# We have 2000 data points, which we'll scatter acrros Age and Income, located on positions 2 and 4 in our data set. 
plt.figure(figsize = (12, 9))
plt.scatter(df_players_2011.iloc[:, 5], df_players_2011.iloc[:, 0])
plt.xlabel('Aces')
plt.ylabel('Ranking')
plt.title('Visualization of raw data')
# Out:
# Text(0.5, 1.0, 'Visualization of raw data')

# %% [markdown]
# ## Standardization

# %%
scaler = StandardScaler()
players_2011_std = scaler.fit_transform(numerical_data)

# %% [markdown]
# ## ${\textbf{Hierarchical Clustering}}$

# %%
# Perform Hierarchical Clustering. The results are returned as a linkage matrix. 
hier_clust = linkage(players_2011_std, method = 'ward')

# %%
# We plot the results from the Hierarchical Clustering using a Dendrogram. 
# We truncate the dendrogram for better readability. The level p shows only the last p merged clusters
# We also omit showing the labels for each point.
plt.figure(figsize = (12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5, 
           show_leaf_counts = False, 
           no_labels = True)
plt.show()

# %% [markdown]
# ## ${\textbf{K-means Clustering}}$

# %%
# Perform K-means clustering. We consider 1 to 10 clusters, so our for loop runs 10 iterations.
# In addition we run the algortihm at many different starting points - k means plus plus. 
# And we set a random state for reproducibility.
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 1)
    kmeans.fit(players_2011_std)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot we choose the number of clusters. 
# We look for a kink in the graphic, after which the descent of wcss isn't as pronounced.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %%
# We run K-means with a fixed number of clusters. In our case 4.
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 1)

# %%
# We divide our data into the four clusters.
kmeans.fit(players_2011_std)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ## Results

# %%
# We create a new data frame with the original features and add a new column with the assigned clusters for each point.
df_players_2011_kmeans = df_players_2011.copy()
df_players_2011_kmeans['Segment K-means'] = kmeans.labels_

# %%
# Calculate mean values for the clusters
df_players_2011_analysis = df_players_2011_kmeans.groupby(['Segment K-means']).mean()
df_players_2011_analysis
# Out:
#                    Ranking        Age       Points  Tourn Played        Aces  \
# Segment K-means
# 0                12.727273  25.954545  3701.363636     24.045455  434.909091
# 1                49.973684  27.973684   942.289474     26.368421  187.052632
# 2                81.281250  25.156250   652.125000     27.031250  110.343750
# 3                33.750000  28.500000  1336.875000     23.375000  561.875000
#
#                  Double Faults  1st Serve %  1st Serve Points Won %  \
# Segment K-means
# 0                   153.136364    60.818182               74.136364
# 1                   124.973684    61.736842               69.000000
# 2                    80.093750    60.000000               67.437500
# 3                   118.375000    62.625000               77.750000
#
#                  2nd Serve Points Won %  Break Points Faced  ...  \
# Segment K-means                                              ...
# 0                             53.136364          354.863636  ...
# 1                             50.368421          319.684211  ...
# 2                             48.906250          186.218750  ...
# 3                             52.375000          221.375000  ...
#
#                  Total Service Points Won %  1st Serve Return Points Won %  \
# Segment K-means
# 0                                 65.863636                      31.772727
# 1                                 61.815789                      30.236842
# 2                                 60.031250                      28.375000
# 3                                 68.125000                      25.250000
#
#                  2nd Serve Return Points Won %  Break Points Opportunities  \
# Segment K-means
# 0                                    52.000000                  494.454545
# 1                                    50.078947                  317.526316
# 2                                    49.062500                  159.937500
# 3                                    44.250000                  233.625000
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# 0                               43.227273           784.636364
# 1                               41.210526           541.447368
# 2                               38.468750           295.500000
# 3                               37.125000           565.500000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# 0                         27.227273            39.681818           52.500000
# 1                         24.157895            38.131579           49.947368
# 2                         20.656250            36.437500           48.375000
# 3                         15.250000            32.500000           50.500000
#
#                  Career Length
# Segment K-means
# 0                     8.272727
# 1                    10.026316
# 2                     7.031250
# 3                     9.750000
#
# [4 rows x 23 columns]

# %%
# Compute the size and proportions of the two clusters
df_players_2011_analysis['N Obs'] = df_players_2011_kmeans[['Segment K-means','Ranking']].groupby(['Segment K-means']).count()
df_players_2011_analysis['Prop Obs'] = df_players_2011_analysis['N Obs'] / df_players_2011_analysis['N Obs'].sum()

# %%
df_players_2011_analysis
# Out:
#                    Ranking        Age       Points  Tourn Played        Aces  \
# Segment K-means
# 0                12.727273  25.954545  3701.363636     24.045455  434.909091
# 1                49.973684  27.973684   942.289474     26.368421  187.052632
# 2                81.281250  25.156250   652.125000     27.031250  110.343750
# 3                33.750000  28.500000  1336.875000     23.375000  561.875000
#
#                  Double Faults  1st Serve %  1st Serve Points Won %  \
# Segment K-means
# 0                   153.136364    60.818182               74.136364
# 1                   124.973684    61.736842               69.000000
# 2                    80.093750    60.000000               67.437500
# 3                   118.375000    62.625000               77.750000
#
#                  2nd Serve Points Won %  Break Points Faced  ...  \
# Segment K-means                                              ...
# 0                             53.136364          354.863636  ...
# 1                             50.368421          319.684211  ...
# 2                             48.906250          186.218750  ...
# 3                             52.375000          221.375000  ...
#
#                  2nd Serve Return Points Won %  Break Points Opportunities  \
# Segment K-means
# 0                                    52.000000                  494.454545
# 1                                    50.078947                  317.526316
# 2                                    49.062500                  159.937500
# 3                                    44.250000                  233.625000
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# 0                               43.227273           784.636364
# 1                               41.210526           541.447368
# 2                               38.468750           295.500000
# 3                               37.125000           565.500000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# 0                         27.227273            39.681818           52.500000
# 1                         24.157895            38.131579           49.947368
# 2                         20.656250            36.437500           48.375000
# 3                         15.250000            32.500000           50.500000
#
#                  Career Length  N Obs  Prop Obs
# Segment K-means
# 0                     8.272727     22      0.22
# 1                    10.026316     38      0.38
# 2                     7.031250     32      0.32
# 3                     9.750000      8      0.08
#
# [4 rows x 25 columns]

# %%
df_players_2011_analysis.rename({0:'Top-Players',
                                 1:'Average-Players',
                                 2:'Worst-Players',
                                 3:'Good-Players'
                                 })
# Out:
#                    Ranking        Age       Points  Tourn Played        Aces  \
# Segment K-means
# Top-Players      12.727273  25.954545  3701.363636     24.045455  434.909091
# Average-Players  49.973684  27.973684   942.289474     26.368421  187.052632
# Worst-Players    81.281250  25.156250   652.125000     27.031250  110.343750
# Good-Players     33.750000  28.500000  1336.875000     23.375000  561.875000
#
#                  Double Faults  1st Serve %  1st Serve Points Won %  \
# Segment K-means
# Top-Players         153.136364    60.818182               74.136364
# Average-Players     124.973684    61.736842               69.000000
# Worst-Players        80.093750    60.000000               67.437500
# Good-Players        118.375000    62.625000               77.750000
#
#                  2nd Serve Points Won %  Break Points Faced  ...  \
# Segment K-means                                              ...
# Top-Players                   53.136364          354.863636  ...
# Average-Players               50.368421          319.684211  ...
# Worst-Players                 48.906250          186.218750  ...
# Good-Players                  52.375000          221.375000  ...
#
#                  2nd Serve Return Points Won %  Break Points Opportunities  \
# Segment K-means
# Top-Players                          52.000000                  494.454545
# Average-Players                      50.078947                  317.526316
# Worst-Players                        49.062500                  159.937500
# Good-Players                         44.250000                  233.625000
#
#                  Break Points Converted %  Return Games Played  \
# Segment K-means
# Top-Players                     43.227273           784.636364
# Average-Players                 41.210526           541.447368
# Worst-Players                   38.468750           295.500000
# Good-Players                    37.125000           565.500000
#
#                  Return Games Won %  Return Points Won %  Total Points Won %  \
# Segment K-means
# Top-Players               27.227273            39.681818           52.500000
# Average-Players           24.157895            38.131579           49.947368
# Worst-Players             20.656250            36.437500           48.375000
# Good-Players              15.250000            32.500000           50.500000
#
#                  Career Length  N Obs  Prop Obs
# Segment K-means
# Top-Players           8.272727     22      0.22
# Average-Players      10.026316     38      0.38
# Worst-Players         7.031250     32      0.32
# Good-Players          9.750000      8      0.08
#
# [4 rows x 25 columns]

# %%
# Add the segment labels to our table
df_players_2011_kmeans['Labels'] = df_players_2011_kmeans['Segment K-means'].map({0:'Top-Players',
                                                                                 1:'Average-Players',
                                                                                 2:'Worst-Players',
                                                                                 3:'Good-Players'
                                                                                 })

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by  "Aces"

# %%
# We plot the results from the K-means algorithm. 
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2011_kmeans['Aces']
y_axis = df_players_2011_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_kmeans['Labels'], palette = ['g', 'r', 'y', 'm'])
plt.title('ATP Top 100 players 2011 K-means')
plt.show() 

#according to correlation map, these are the variables that have the highest impact on ranking 
#'Service Games Played'
#'Return Games Played'
#'Total Points Won %'
##SO, overall, experience is most valuable, it might explain the next gen tournement founded at 2017
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by "Break Points Opportunities"

# %%
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2011_kmeans['Break Points Opportunities']
y_axis = df_players_2011_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_kmeans['Labels'], palette = ['g', 'r', 'y', 'm'])
plt.title('ATP Top 100 players 2011 K-means')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### We plot the results from the K-means algorithm clustering players by "Return Games Won"

# %%
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
x_axis = df_players_2011_kmeans['Return Games Won %']
y_axis = df_players_2011_kmeans['Ranking']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_kmeans['Labels'], palette = ['g', 'r', 'y', 'm'])
plt.title('ATP Top 100 players 2011 K-means')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## PCA Analysis

# %%
# Employ PCA to find a subset of components, which explain the variance in the data.
pca = PCA()

# %%
# Fit PCA with our standardized data.
pca.fit(players_2011_std)
# Out:
# PCA()

# %%
# The attribute shows how much variance is explained by each of the seven individual components.
pca.explained_variance_ratio_
# Out:
# array([4.15850921e-01, 2.19114392e-01, 9.15525636e-02, 7.67667931e-02,
#        4.59169139e-02, 3.22986504e-02, 2.30935444e-02, 2.11959231e-02,
#        1.61342350e-02, 1.56346761e-02, 1.29300242e-02, 8.94776225e-03,
#        7.81851154e-03, 5.51785868e-03, 2.65555608e-03, 1.36600959e-03,
#        9.76909060e-04, 6.45061136e-04, 5.63328601e-04, 5.23098478e-04,
#        2.62906878e-04, 2.15711788e-04, 1.86494817e-05])

# %%
# Plot the cumulative variance explained by total number of components.
# On this graph we choose the subset of components we want to keep. 
# Generally, we want to keep around 80 % of the explained variance.
plt.figure(figsize = (12,9))
plt.plot(range(1,24), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
# We choose three components. 5 seems the right choice according to the previous graph, due to it allows to preserve 
#around 85% of the data with only 1/5 of the variables.
pca = PCA(n_components = 5)

# %%
#Fit the model the our data with the selected number of components. In our case three.
pca.fit(players_2011_std)
# Out:
# PCA(n_components=5)

# %% [markdown]
# ### ${\textbf{PCA Results}}$

# %%
# Here we discucss the results from the PCA.
# The components attribute shows the loadings of each component on each of the seven original features.
# The loadings are the correlations between the components and the original features. 
pca.components_
# Out:
# array([[ 2.87381082e-01, -5.35102261e-03, -2.28401951e-01,
#          1.47112279e-01, -2.22731422e-01, -1.99693223e-01,
#         -3.74523665e-02, -2.09011004e-01, -2.06447478e-01,
#         -2.29889198e-01, -1.85050236e-01, -3.02604420e-01,
#         -2.34269240e-01, -2.41832267e-01, -1.47534926e-01,
#         -1.21959681e-01, -2.97217752e-01, -1.30477931e-01,
#         -3.01061349e-01, -1.65823668e-01, -1.50974479e-01,
#         -3.01133709e-01, -2.71601941e-02],
#        [-9.87990246e-03,  2.86059587e-02, -6.44481069e-02,
#         -9.58695470e-02,  2.37198538e-01, -2.70071936e-02,
#          2.63317300e-02,  2.76449780e-01,  1.54948710e-01,
#         -1.51731670e-01,  2.34390711e-01,  3.24074914e-04,
#          2.84589094e-01,  2.72511992e-01, -3.41462201e-01,
#         -3.54321319e-01, -1.19301960e-01, -2.51832862e-01,
#         -1.75230016e-03, -3.63993680e-01, -3.76886824e-01,
#         -7.19509473e-03,  4.69392472e-03],
#        [-4.44049180e-03, -5.53802205e-01, -8.68565560e-02,
#          2.90966427e-01,  1.79166145e-01,  2.33985485e-01,
#         -2.90578213e-01,  9.53830469e-02, -1.56681713e-01,
#          1.31176419e-01, -9.68949872e-02,  1.04268892e-01,
#         -3.38386825e-02, -4.26893309e-02,  2.51621163e-03,
#         -7.88900315e-02,  4.93040623e-02, -3.25455396e-02,
#          1.08575739e-01, -6.93406224e-02, -5.02840180e-02,
#         -7.94080181e-02, -5.66179345e-01],
#        [ 4.41847430e-02, -3.92187542e-01,  2.32855225e-01,
#         -4.03498168e-01, -7.53006257e-02, -3.77458906e-01,
#          5.44444737e-02,  4.53174702e-02,  1.71004407e-01,
#         -3.45107795e-01,  4.81804505e-02, -1.91855850e-01,
#          9.31002320e-02,  1.11190253e-01,  1.26532314e-01,
#          9.93951008e-02, -1.00373495e-01,  4.41560250e-02,
#         -2.01308129e-01,  1.12729088e-01,  1.16665422e-01,
#          1.81496734e-01, -3.57545916e-01],
#        [-6.14770780e-02, -1.65595057e-01,  6.40485424e-02,
#          1.36428343e-01, -8.80697929e-02, -4.41571519e-02,
#          7.83811115e-01, -3.24170632e-01,  1.45148400e-01,
#          1.66404067e-01, -2.06911207e-02,  1.00657124e-01,
#         -2.31833019e-02, -2.60757738e-02,  1.57966944e-03,
#         -8.84901441e-02,  1.14029600e-01, -2.87411770e-01,
#          1.00459970e-01, -7.51876807e-02, -3.93911117e-02,
#         -6.80659382e-02, -1.76137077e-01]])

# %%
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = numerical_data.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5'])
df_pca_comp
# Out:
#               Ranking       Age    Points  Tourn Played      Aces  \
# Component 1  0.287381 -0.005351 -0.228402      0.147112 -0.222731
# Component 2 -0.009880  0.028606 -0.064448     -0.095870  0.237199
# Component 3 -0.004440 -0.553802 -0.086857      0.290966  0.179166
# Component 4  0.044185 -0.392188  0.232855     -0.403498 -0.075301
# Component 5 -0.061477 -0.165595  0.064049      0.136428 -0.088070
#
#              Double Faults  1st Serve %  1st Serve Points Won %  \
# Component 1      -0.199693    -0.037452               -0.209011
# Component 2      -0.027007     0.026332                0.276450
# Component 3       0.233985    -0.290578                0.095383
# Component 4      -0.377459     0.054444                0.045317
# Component 5      -0.044157     0.783811               -0.324171
#
#              2nd Serve Points Won %  Break Points Faced  ...  \
# Component 1               -0.206447           -0.229889  ...
# Component 2                0.154949           -0.151732  ...
# Component 3               -0.156682            0.131176  ...
# Component 4                0.171004           -0.345108  ...
# Component 5                0.145148            0.166404  ...
#
#              Total Service Points Won %  1st Serve Return Points Won %  \
# Component 1                   -0.241832                      -0.147535
# Component 2                    0.272512                      -0.341462
# Component 3                   -0.042689                       0.002516
# Component 4                    0.111190                       0.126532
# Component 5                   -0.026076                       0.001580
#
#              2nd Serve Return Points Won %  Break Points Opportunities  \
# Component 1                      -0.121960                   -0.297218
# Component 2                      -0.354321                   -0.119302
# Component 3                      -0.078890                    0.049304
# Component 4                       0.099395                   -0.100373
# Component 5                      -0.088490                    0.114030
#
#              Break Points Converted %  Return Games Played  \
# Component 1                 -0.130478            -0.301061
# Component 2                 -0.251833            -0.001752
# Component 3                 -0.032546             0.108576
# Component 4                  0.044156            -0.201308
# Component 5                 -0.287412             0.100460
#
#              Return Games Won %  Return Points Won %  Total Points Won %  \
# Component 1           -0.165824            -0.150974           -0.301134
# Component 2           -0.363994            -0.376887           -0.007195
# Component 3           -0.069341            -0.050284           -0.079408
# Component 4            0.112729             0.116665            0.181497
# Component 5           -0.075188            -0.039391           -0.068066
#
#              Career Length
# Component 1      -0.027160
# Component 2       0.004694
# Component 3      -0.566179
# Component 4      -0.357546
# Component 5      -0.176137
#
# [5 rows x 23 columns]

# %%
# Heat Map for Principal Components against original features. Again we use the RdBu color scheme and set borders to -1 and 1.
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu')
plt.yticks([0, 1, 2, 3 ,4], 
           ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5'],
           rotation = 45,
           fontsize = 9)
# Out:
# ([<matplotlib.axis.YTick at 0x248e4862248>,
#   <matplotlib.axis.YTick at 0x248e4854608>,
#   <matplotlib.axis.YTick at 0x248e4648a08>,
#   <matplotlib.axis.YTick at 0x248e467b888>,
#   <matplotlib.axis.YTick at 0x248e467f488>],
#  [Text(0, 0, 'Component 1'),
#   Text(0, 1, 'Component 2'),
#   Text(0, 2, 'Component 3'),
#   Text(0, 3, 'Component 4'),
#   Text(0, 4, 'Component 5')])

# %%
##we had the loadings (correlation of between each original variable and a component) mapped before, but we'll now reduce
##the dimensionality to 5 components to make it more manageable

pca.transform(players_2011_std)
# Out:
# array([[-8.59793549e+00, -3.13477124e+00, -1.28748830e+00,
#          3.72970632e+00,  5.99468793e-01],
#        [-7.31108963e+00, -2.55557477e+00, -1.60984168e+00,
#          1.98979661e+00,  1.77833975e+00],
#        [-6.87817164e+00,  1.20221891e+00, -2.64179407e+00,
#          1.67617157e+00, -1.21475965e-01],
#        [-6.29465350e+00, -3.22776589e+00,  6.52840811e-01,
#          2.10575357e+00, -7.47140610e-01],
#        [-6.20372220e+00, -2.08472110e+00, -1.06662954e+00,
#         -2.98117302e-01, -1.93129471e-01],
#        [-5.43900335e+00,  2.43177159e+00,  1.56209618e+00,
#         -1.04610023e+00,  1.96832510e-01],
#        [-4.69478305e+00, -1.75831291e-01,  4.26159751e-01,
#          3.74454713e-01, -1.13821882e+00],
#        [-4.27115281e+00,  7.95059928e-01, -8.65310495e-01,
#         -2.84789046e-01, -6.10358994e-01],
#        [-4.63215765e+00, -4.20874158e-01,  7.38046868e-01,
#         -6.33920702e-01, -9.84904766e-01],
#        [-3.54645243e+00,  9.30326090e-01,  1.76107088e+00,
#         -1.36425812e+00, -5.38042563e-01],
#        [-4.03845972e+00,  1.31716256e+00,  4.89373698e-01,
#          2.00995593e+00, -1.85931456e-01],
#        [-3.08180632e+00, -2.33346960e+00,  1.12766190e+00,
#         -1.30115513e+00, -5.03166205e-01],
#        [-2.95107790e+00,  1.28026869e-01, -1.09880127e+00,
#          1.32089258e+00, -6.84020295e-01],
#        [-2.73556341e+00,  3.09460289e+00, -1.85326217e+00,
#          1.11750296e+00, -1.31849333e-01],
#        [-2.91264454e+00, -2.08408833e-01,  3.68876254e+00,
#         -1.45381849e+00, -1.45073272e+00],
#        [-3.12689845e+00, -2.54847755e-02,  7.86142327e-01,
#          1.13347807e-01,  5.49603565e-01],
#        [-2.24110667e+00, -2.90962508e-01, -3.63042943e-03,
#          2.09949519e-01,  4.52587892e-01],
#        [-2.41807061e+00,  6.37641290e+00,  1.26194394e+00,
#         -5.40608634e-02,  2.10198567e+00],
#        [-2.00844520e+00, -1.73718993e-01, -5.70786025e-01,
#          1.38330146e+00,  3.38019932e-01],
#        [-2.58881303e+00,  4.55263430e+00,  3.19560963e-01,
#         -3.29638240e+00, -6.59896191e-01],
#        [-3.14405720e+00,  6.62949738e-01,  1.97454581e+00,
#          4.32080561e-01, -1.26966003e+00],
#        [-2.37603003e+00, -1.50093142e+00,  1.97403492e+00,
#         -3.96383335e-01, -1.85895927e-01],
#        [-2.54094385e+00, -1.78920792e+00, -9.43909973e-02,
#         -1.14002347e+00,  2.70532964e-02],
#        [-2.67785935e+00, -1.87350388e-01, -3.33451846e-01,
#         -1.50178774e+00,  1.40393769e+00],
#        [-1.16562215e+00, -9.96562800e-01,  1.94897157e+00,
#          5.32596982e-01,  1.14995246e+00],
#        [-1.21341042e+00, -2.64573944e+00, -7.07765515e-01,
#         -3.14339193e-02,  1.63010153e+00],
#        [-1.09609140e-01, -1.25080049e+00,  3.18745112e-01,
#          2.98451458e-01,  5.43349977e-01],
#        [-1.21494502e+00, -5.40793884e-01, -2.01455341e+00,
#         -2.00213315e+00, -4.29456126e-01],
#        [-1.57736070e+00, -3.78548874e+00, -2.01193156e+00,
#         -1.63593804e+00,  8.50117002e-01],
#        [-9.35384108e-01,  2.54305576e+00, -1.69625591e+00,
#         -3.93482320e-01, -2.03889321e+00],
#        [-1.62817510e+00,  4.66840729e+00,  2.12684898e+00,
#          1.88760306e+00,  6.42868606e-01],
#        [-3.29332523e+00,  2.56351372e+00,  1.66653507e+00,
#         -2.55214402e-01,  1.61426385e+00],
#        [-4.15563809e-01, -6.95238469e-01, -1.69501506e+00,
#         -1.54211656e-01,  5.42010984e-02],
#        [-5.52354504e-01, -6.82788536e-01, -6.37107021e-01,
#         -1.09698782e+00,  2.62932932e+00],
#        [-9.48677770e-01, -3.89608556e-01, -7.98169768e-01,
#         -1.33076608e+00,  2.41816064e-01],
#        [ 3.99827115e-02,  8.55019809e-01,  1.28874962e+00,
#         -9.31128729e-01, -1.34495038e-01],
#        [-6.40867702e-01, -1.93232419e-01,  1.62284051e+00,
#          1.39874127e-01,  4.46416053e-01],
#        [-2.69422138e-01, -3.77276930e-01,  5.28341001e-01,
#         -8.47766112e-01, -3.93324432e-01],
#        [ 5.53596266e-01, -1.28680694e+00,  4.97187026e-01,
#          1.34912594e+00,  7.08933174e-01],
#        [ 8.46287743e-01,  1.47403521e+00, -7.20790536e-01,
#         -1.09257411e+00, -3.76053301e-01],
#        [-9.36487995e-01, -2.88193746e+00, -1.61809607e+00,
#         -1.48717935e+00,  1.78437373e+00],
#        [ 1.30944257e+00,  2.04930109e+00,  1.28320712e+00,
#          2.66930068e+00,  1.67037819e+00],
#        [-1.11686442e+00,  1.37938212e+00,  1.97009776e-01,
#         -1.34826735e+00, -3.58154241e-01],
#        [-1.37616908e+00,  9.25800972e-01,  1.63605733e+00,
#         -9.60274890e-01, -1.86925019e+00],
#        [-1.58409332e+00, -1.04156809e+00,  1.26246738e+00,
#          1.20797788e-01, -2.19066932e-02],
#        [ 4.45532848e-01, -2.74977329e+00,  1.01004989e+00,
#         -1.21375517e+00,  8.86808236e-01],
#        [ 4.39118441e-01,  3.23093133e+00, -1.45887586e+00,
#         -9.10652126e-01, -3.85438018e-01],
#        [ 1.20864522e-01, -3.64659396e+00,  2.47366241e+00,
#         -2.18362011e+00,  2.03763641e-01],
#        [-1.05701721e+00, -1.48106669e-01, -1.40107330e+00,
#         -7.09569386e-01, -1.76842847e+00],
#        [-2.85101791e-01, -1.46960203e-01, -3.61791167e+00,
#          1.51869598e+00, -1.02633082e-01],
#        [-4.17271253e-01, -3.13615190e-02, -2.66209224e+00,
#          1.26386850e+00, -5.62591216e-01],
#        [ 2.93239440e-01,  7.72674308e-01, -8.79781595e-01,
#         -1.15634531e+00,  1.06313999e-01],
#        [-8.00005737e-01, -1.12955895e+00, -6.82278236e-01,
#         -1.89493261e+00, -8.19990327e-01],
#        [ 1.14223727e+00,  6.25846720e+00, -8.11711103e-01,
#          6.45895480e-01, -1.31521814e+00],
#        [-5.08788588e-01, -9.16433289e-01,  6.28758907e-01,
#          1.52419865e-01,  9.42439518e-01],
#        [ 6.06355063e-01,  7.94209189e+00, -1.38319059e+00,
#         -9.27604853e-01,  4.40925143e-02],
#        [ 2.63628975e-02, -9.09561387e-01, -2.46408288e-01,
#         -8.44551415e-01, -6.71355069e-01],
#        [ 9.34377623e-01,  7.05760886e-01, -1.54957271e+00,
#         -1.00060377e+00,  2.58318237e+00],
#        [ 6.23484701e-01,  1.46888928e+00, -1.49261464e+00,
#         -4.27428058e-01, -2.11207038e+00],
#        [ 1.59845133e+00, -2.23699083e+00,  1.08155061e-01,
#         -1.23131949e+00,  6.66738127e-01],
#        [ 8.72048915e-01,  2.25033370e+00,  1.60927199e+00,
#         -2.00505180e-01,  3.54740862e-02],
#        [ 7.94091991e-01,  1.00638009e-01,  9.82837523e-01,
#         -6.52056795e-01,  1.03875825e+00],
#        [-1.70294780e-01,  1.54361496e+00,  4.61731585e-01,
#         -5.11344823e-01, -1.40624504e+00],
#        [ 2.94620530e-01, -6.53365820e-01, -1.66160569e+00,
#          8.93175521e-01, -1.25431084e+00],
#        [ 2.27532450e-01, -1.57756213e+00,  1.40736169e+00,
#         -2.57962863e+00, -7.13354930e-01],
#        [ 1.68235236e+00, -4.30855644e-01,  1.37594588e+00,
#          1.07622538e+00,  5.01250634e-01],
#        [ 2.51400888e+00, -8.16901172e-02, -1.80718778e+00,
#         -2.11298911e-01, -7.96938145e-01],
#        [ 5.94395635e+00, -2.54305800e+00, -3.39218145e-01,
#         -1.26039853e-02,  6.32286700e-01],
#        [ 3.13173596e+00, -4.76358146e+00, -1.92890089e+00,
#         -1.42373852e+00,  8.95037799e-01],
#        [ 3.93703265e+00,  1.31118973e+00,  7.15184829e-01,
#          2.37587886e-01, -3.64468703e-01],
#        [ 1.86701699e+00, -1.17466423e+00, -1.25874113e+00,
#         -7.50967810e-01, -8.10932413e-01],
#        [ 1.64293159e+00, -1.62857943e+00,  1.18238532e+00,
#          5.31347377e-01,  3.72846199e-02],
#        [ 2.86637026e+00,  4.67902369e-01,  3.53234998e-01,
#          2.48048163e-01,  1.22369046e+00],
#        [ 2.19795611e+00, -1.00256332e+00, -1.44717237e+00,
#          6.54979848e-01, -6.62548524e-01],
#        [ 4.93935692e+00, -2.62962803e+00, -9.79810200e-01,
#          3.76649980e-01,  7.77438062e-01],
#        [ 1.06083133e+00,  6.30700431e-01,  2.89462176e+00,
#          7.07484927e-01,  8.01039156e-01],
#        [ 9.36210087e-01, -7.25795259e-01, -1.05228784e+00,
#         -1.24456047e+00,  6.06146179e-01],
#        [ 3.81739235e+00,  2.20749984e+00, -6.75894344e-01,
#          2.34431045e+00, -1.23183714e-01],
#        [ 1.69478623e+00,  2.51678569e-01,  2.51555824e+00,
#          1.23731490e+00, -1.88050937e-01],
#        [ 1.73927226e+00,  1.43320108e+00, -1.57408526e+00,
#          8.55963856e-01, -8.97092360e-01],
#        [ 4.09980141e+00, -5.08198808e+00,  1.16211364e+00,
#          4.09319696e+00, -1.21611640e+00],
#        [ 2.77547395e+00,  9.46090686e-01, -4.29591122e-01,
#         -7.12206334e-01, -8.27638369e-02],
#        [ 3.06465525e+00, -2.45198396e-01, -5.82549324e-01,
#          1.30538335e+00, -8.10365988e-01],
#        [ 1.32712633e+00, -1.07984101e+00,  7.21962083e-01,
#          1.12074088e+00,  8.17988168e-01],
#        [ 3.52510647e+00,  5.67247207e-01, -2.36757504e+00,
#          7.76925877e-02, -3.22658804e-01],
#        [ 3.01798922e+00,  3.51011347e-01,  2.66192355e-01,
#          2.30098641e+00, -5.72659498e-01],
#        [ 2.53609600e+00, -6.13947596e-01,  1.62453719e+00,
#         -5.73458331e-01,  5.98753312e-01],
#        [ 2.92241473e+00, -2.72054100e-01, -9.18488881e-01,
#          2.04097446e+00, -1.42465059e+00],
#        [ 3.70958379e+00, -3.06674661e-01,  2.23630648e+00,
#         -9.40855896e-01, -8.76081006e-01],
#        [ 1.25822924e+00, -9.16721349e-02, -1.67561320e+00,
#         -3.10663688e-01,  8.51193245e-01],
#        [ 2.76112698e+00, -1.07358480e+00,  1.15424626e+00,
#          7.06479423e-01,  6.14958468e-02],
#        [ 2.21826880e+00, -2.56938156e+00,  6.37059251e-01,
#          8.73723891e-01,  1.19264764e-01],
#        [ 1.69252874e+00,  2.50790796e+00,  6.93703677e-01,
#          1.78247777e+00,  8.28734386e-03],
#        [ 4.16212890e+00,  1.23773282e+00,  6.82163647e-01,
#          1.77173834e+00, -5.67988736e-01],
#        [ 4.49028503e+00, -1.22047609e+00,  2.68356768e+00,
#          9.69944183e-01, -1.86050976e+00],
#        [ 2.19983998e+00, -1.89917953e+00,  1.44169427e+00,
#         -6.49407497e-01, -1.78375415e-01],
#        [ 9.39305702e+00, -2.49059902e+00, -5.53172042e-01,
#         -1.16909787e+00, -1.15488389e+00],
#        [ 8.12255320e+00,  5.75111887e+00, -2.52999629e-01,
#          4.26204180e-01,  3.43529444e+00],
#        [ 2.99521318e+00, -5.98249226e-01, -1.71922058e+00,
#         -1.67782732e+00, -4.96910000e-01],
#        [ 1.51739415e+00,  1.66008117e+00, -1.42681232e+00,
#         -1.21541509e+00,  2.56819185e-01]])

# %%
scores_pca = pca.transform(players_2011_std)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA}}$

# %%
# We fit K means using the transformed data from the PCA.
wcss = []
##within clusters sum of squares (wcss)
for i in range(1,11):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 1)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
# Plot the Within Cluster Sum of Squares for the K-means PCA model. Here we make a decission about the number of clusters.
# Again it looks like four is the best option.
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
# We have chosen four clusters, so we run K-means with number of clusters equals four. 
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state =1)

# %%
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ### ${\textbf{K-means clustering with PCA Results}}$

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters.
df_players_2011_pca_kmeans = pd.concat([df_players_2011.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
df_players_2011_pca_kmeans.columns.values[-5: ] = ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5']
# The last column we add contains the pca k-means clustering labels.
df_players_2011_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

# %%
df_players_2011_pca_kmeans
# Out:
#     Ranking           Player  Age  Points  Tourn Played  Aces  Double Faults  \
# 0         1   Novak Djokovic   24   13630            19   343            143
# 1         2     Rafael Nadal   25    9595            20   267            121
# 2         3    Roger Federer   30    8170            19   504             98
# 3         4      Andy Murray   24    7380            19   494            149
# 4         5     David Ferrer   29    4925            23   265            200
# ..      ...              ...  ...     ...           ...   ...            ...
# 95       96     Tobias Kamke   25     582            33    87            134
# 96       97      Eric Prodon   30     581            29     7             17
# 97       98     Andreas Beck   25     580            30     8              4
# 98       99  Michael Russell   33     577            29    88            127
# 99      100   Michael Berrer   31     567            26   194            114
#
#     1st Serve %  1st Serve Points Won %  2nd Serve Points Won %  ...  \
# 0            65                      74                      56  ...
# 1            68                      71                      57  ...
# 2            64                      79                      57  ...
# 3            59                      75                      50  ...
# 4            61                      72                      55  ...
# ..          ...                     ...                     ...  ...
# 95           57                      66                      50  ...
# 96           54                      57                      39  ...
# 97           65                      63                      54  ...
# 98           64                      69                      47  ...
# 99           64                      71                      49  ...
#
#     Return Games Won %  Return Points Won %  Total Points Won %  \
# 0                   39                   45                  56
# 1                   34                   43                  54
# 2                   28                   40                  55
# 3                   36                   44                  54
# 4                   33                   42                  54
# ..                 ...                  ...                 ...
# 95                  25                   38                  49
# 96                  18                   35                  42
# 97                   2                   28                  44
# 98                  22                   36                  49
# 99                  17                   35                  49
#
#     Career Length  Component 1  Component 2  Component 3  Component 4  \
# 0               8    -8.597935    -3.134771    -1.287488     3.729706
# 1              10    -7.311090    -2.555575    -1.609842     1.989797
# 2              13    -6.878172     1.202219    -2.641794     1.676172
# 3               6    -6.294654    -3.227766     0.652841     2.105754
# 4              11    -6.203722    -2.084721    -1.066630    -0.298117
# ..            ...          ...          ...          ...          ...
# 95              7     2.199840    -1.899180     1.441694    -0.649407
# 96             11     9.393057    -2.490599    -0.553172    -1.169098
# 97              8     8.122553     5.751119    -0.253000     0.426204
# 98             13     2.995213    -0.598249    -1.719221    -1.677827
# 99             12     1.517394     1.660081    -1.426812    -1.215415
#
#     Component 5  Segment K-means PCA
# 0      0.599469                    1
# 1      1.778340                    1
# 2     -0.121476                    1
# 3     -0.747141                    1
# 4     -0.193129                    1
# ..          ...                  ...
# 95    -0.178375                    0
# 96    -1.154884                    0
# 97     3.435294                    0
# 98    -0.496910                    0
# 99     0.256819                    2
#
# [100 rows x 30 columns]

# %%
# We calculate the means by segments.
df_players_2011_pca_kmeans_freq = df_players_2011_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_players_2011_pca_kmeans_freq
# Out:
#                        Ranking        Age       Points  Tourn Played  \
# Segment K-means PCA
# 0                    82.931034  25.482759   638.758621     27.413793
# 1                    12.727273  25.954545  3701.363636     24.045455
# 2                    47.941176  27.411765  1064.294118     24.117647
# 3                    48.437500  27.843750   961.031250     26.531250
#
#                            Aces  Double Faults  1st Serve %  \
# Segment K-means PCA
# 0                     94.034483      77.344828    59.758621
# 1                    434.909091     153.136364    60.818182
# 2                    408.470588     122.588235    60.882353
# 3                    170.718750     122.875000    62.468750
#
#                      1st Serve Points Won %  2nd Serve Points Won %  \
# Segment K-means PCA
# 0                                 66.896552               48.862069
# 1                                 74.136364               53.136364
# 2                                 75.176471               51.176471
# 3                                 68.250000               50.343750
#
#                      Break Points Faced  ...  Return Games Played  \
# Segment K-means PCA                      ...
# 0                            184.000000  ...           284.551724
# 1                            354.863636  ...           784.636364
# 2                            243.941176  ...           522.882353
# 3                            324.843750  ...           544.187500
#
#                      Return Games Won %  Return Points Won %  \
# Segment K-means PCA
# 0                             21.000000            36.586207
# 1                             27.227273            39.681818
# 2                             17.294118            34.058824
# 3                             24.937500            38.593750
#
#                      Total Points Won %  Career Length  Component 1  \
# Segment K-means PCA
# 0                             48.241379       7.241379     3.357137
# 1                             52.500000       8.272727    -4.193717
# 2                             50.058824       9.176471    -0.230614
# 3                             50.000000       9.937500    -0.036711
#
#                      Component 2  Component 3  Component 4  Component 5
# Segment K-means PCA
# 0                      -0.365937     0.275855     0.621042    -0.123809
# 1                      -0.367184     0.330688     0.257720    -0.075117
# 2                       3.172115    -0.073775    -0.190307    -0.346657
# 3                      -1.101117    -0.438149    -0.638902     0.348006
#
# [4 rows x 28 columns]

# %%
# Calculate the size of each cluster and its proportion to the entire data set.
df_players_2011_pca_kmeans_freq['N Obs'] = df_players_2011_pca_kmeans[['Segment K-means PCA','Ranking']].groupby(['Segment K-means PCA']).count()
df_players_2011_pca_kmeans_freq['Prop Obs'] = df_players_2011_pca_kmeans_freq['N Obs'] / df_players_2011_pca_kmeans_freq['N Obs'].sum()
df_players_2011_pca_kmeans_freq = df_players_2011_pca_kmeans_freq.rename({0:'Worst Players', 
                                                          1:'Top Players',
                                                          2:'Good Players',
                                                          3: 'Average Players'})               
df_players_2011_pca_kmeans_freq
# Out:
#                        Ranking        Age       Points  Tourn Played  \
# Segment K-means PCA
# Worst Players        82.931034  25.482759   638.758621     27.413793
# Top Players          12.727273  25.954545  3701.363636     24.045455
# Good Players         47.941176  27.411765  1064.294118     24.117647
# Average Players      48.437500  27.843750   961.031250     26.531250
#
#                            Aces  Double Faults  1st Serve %  \
# Segment K-means PCA
# Worst Players         94.034483      77.344828    59.758621
# Top Players          434.909091     153.136364    60.818182
# Good Players         408.470588     122.588235    60.882353
# Average Players      170.718750     122.875000    62.468750
#
#                      1st Serve Points Won %  2nd Serve Points Won %  \
# Segment K-means PCA
# Worst Players                     66.896552               48.862069
# Top Players                       74.136364               53.136364
# Good Players                      75.176471               51.176471
# Average Players                   68.250000               50.343750
#
#                      Break Points Faced  ...  Return Points Won %  \
# Segment K-means PCA                      ...
# Worst Players                184.000000  ...            36.586207
# Top Players                  354.863636  ...            39.681818
# Good Players                 243.941176  ...            34.058824
# Average Players              324.843750  ...            38.593750
#
#                      Total Points Won %  Career Length  Component 1  \
# Segment K-means PCA
# Worst Players                 48.241379       7.241379     3.357137
# Top Players                   52.500000       8.272727    -4.193717
# Good Players                  50.058824       9.176471    -0.230614
# Average Players               50.000000       9.937500    -0.036711
#
#                      Component 2  Component 3  Component 4  Component 5  \
# Segment K-means PCA
# Worst Players          -0.365937     0.275855     0.621042    -0.123809
# Top Players            -0.367184     0.330688     0.257720    -0.075117
# Good Players            3.172115    -0.073775    -0.190307    -0.346657
# Average Players        -1.101117    -0.438149    -0.638902     0.348006
#
#                      N Obs  Prop Obs
# Segment K-means PCA
# Worst Players           29      0.29
# Top Players             22      0.22
# Good Players            17      0.17
# Average Players         32      0.32
#
# [4 rows x 30 columns]

# %%
df_players_2011_pca_kmeans['Legend'] = df_players_2011_pca_kmeans['Segment K-means PCA'].map({0:'Worst Players', 
                                                          1:'Top Players',
                                                          2:'Good Players',
                                                          3: 'Average Players'})

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
x_axis = df_players_2011_pca_kmeans['Component 1']
y_axis = df_players_2011_pca_kmeans['Component 2']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = df_players_2011_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# C:\Users\Vanessa\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
